# %%
import gensim#For word2vec, etc
import requests #For downloading our datasets
import lucem_illud_2020

import numpy as np #For arrays
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import sklearn.metrics.pairwise #For cosine similarity
import sklearn.manifold #For T-SNE
import sklearn.decomposition #For PCA
import pandas as pd
from tqdm import tqdm_notebook as tqdm
import re
from nltk.corpus import stopwords

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path 
stop_words = set(stopwords.words('english'))
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
df = pd.read_csv("/Users/shiyipeng/Downloads/myanimelist-comment-dataset/animeReviewsOrderByTime.csv",error_bad_lines=False)
# Out:
# b'Skipping line 5: expected 29 fields, saw 44\nSkipping line 15: expected 29 fields, saw 35\nSkipping line 22: expected 29 fields, saw 36\nSkipping line 24: expected 29 fields, saw 71\nSkipping line 25: expected 29 fields, saw 45\nSkipping line 26: expected 29 fields, saw 76\nSkipping line 35: expected 29 fields, saw 42\nSkipping line 40: expected 29 fields, saw 40\nSkipping line 42: expected 29 fields, saw 66\nSkipping line 45: expected 29 fields, saw 44\nSkipping line 48: expected 29 fields, saw 42\nSkipping line 51: expected 29 fields, saw 35\nSkipping line 53: expected 29 fields, saw 42\nSkipping line 75: expected 29 fields, saw 62\nSkipping line 76: expected 29 fields, saw 57\nSkipping line 77: expected 29 fields, saw 45\nSkipping line 85: expected 29 fields, saw 33\nSkipping line 89: expected 29 fields, saw 92\nSkipping line 92: expected 29 fields, saw 31\nSkipping line 95: expected 29 fields, saw 74\nSkipping line 100: expected 29 fields, saw 61\nSkipping line 105: expected 29 fields, saw 92\nSkipping line 118: expected 29 fields, saw 33\nSkipping line 124: expected 29 fields, saw 213\nSkipping line 130: expected 29 fields, saw 107\nSkipping line 131: expected 29 fields, saw 35\nSkipping line 135: expected 29 fields, saw 75\nSkipping line 136: expected 29 fields, saw 77\nSkipping line 138: expected 29 fields, saw 32\nSkipping line 148: expected 29 fields, saw 32\nSkipping line 154: expected 29 fields, saw 35\nSkipping line 183: expected 29 fields, saw 46\nSkipping line 314: expected 29 fields, saw 185\nSkipping line 328: expected 29 fields, saw 41\nSkipping line 548: expected 29 fields, saw 31\nSkipping line 597: expected 29 fields, saw 58\nSkipping line 657: expected 29 fields, saw 33\nSkipping line 662: expected 29 fields, saw 34\nSkipping line 794: expected 29 fields, saw 34\nSkipping line 857: expected 29 fields, saw 41\nSkipping line 865: expected 29 fields, saw 38\nSkipping line 898: expected 29 fields, saw 57\nSkipping line 910: expected 29 fields, saw 44\nSkipping line 1062: expected 29 fields, saw 50\nSkipping line 1227: expected 29 fields, saw 56\nSkipping line 1303: expected 29 fields, saw 137\nSkipping line 1324: expected 29 fields, saw 83\nSkipping line 1327: expected 29 fields, saw 133\nSkipping line 1348: expected 29 fields, saw 31\nSkipping line 1601: expected 29 fields, saw 114\nSkipping line 1667: expected 29 fields, saw 66\nSkipping line 1722: expected 29 fields, saw 36\nSkipping line 1909: expected 29 fields, saw 32\nSkipping line 1911: expected 29 fields, saw 43\nSkipping line 1912: expected 29 fields, saw 33\nSkipping line 1917: expected 29 fields, saw 50\nSkipping line 1954: expected 29 fields, saw 51\nSkipping line 2111: expected 29 fields, saw 48\nSkipping line 2133: expected 29 fields, saw 48\nSkipping line 2168: expected 29 fields, saw 44\nSkipping line 2209: expected 29 fields, saw 73\nSkipping line 2409: expected 29 fields, saw 36\nSkipping line 2440: expected 29 fields, saw 51\nSkipping line 2453: expected 29 fields, saw 39\nSkipping line 2455: expected 29 fields, saw 34\nSkipping line 2557: expected 29 fields, saw 58\nSkipping line 2563: expected 29 fields, saw 31\nSkipping line 2818: expected 29 fields, saw 72\nSkipping line 2833: expected 29 fields, saw 48\nSkipping line 2842: expected 29 fields, saw 31\nSkipping line 2845: expected 29 fields, saw 51\nSkipping line 2982: expected 29 fields, saw 38\nSkipping line 3008: expected 29 fields, saw 47\nSkipping line 3077: expected 29 fields, saw 31\nSkipping line 3096: expected 29 fields, saw 86\nSkipping line 3128: expected 29 fields, saw 30\nSkipping line 3129: expected 29 fields, saw 85\nSkipping line 3292: expected 29 fields, saw 34\nSkipping line 3346: expected 29 fields, saw 39\nSkipping line 3423: expected 29 fields, saw 83\nSkipping line 3426: expected 29 fields, saw 50\nSkipping line 3465: expected 29 fields, saw 62\nSkipping line 3467: expected 29 fields, saw 32\nSkipping line 3601: expected 29 fields, saw 53\nSkipping line 3713: expe ...
# b'Skipping line 38709: expected 29 fields, saw 39\nSkipping line 38712: expected 29 fields, saw 44\nSkipping line 38718: expected 29 fields, saw 83\nSkipping line 38722: expected 29 fields, saw 31\nSkipping line 38727: expected 29 fields, saw 31\nSkipping line 38732: expected 29 fields, saw 61\nSkipping line 38738: expected 29 fields, saw 34\nSkipping line 38750: expected 29 fields, saw 30\nSkipping line 38762: expected 29 fields, saw 66\nSkipping line 38779: expected 29 fields, saw 32\nSkipping line 38793: expected 29 fields, saw 187\nSkipping line 38798: expected 29 fields, saw 37\nSkipping line 38799: expected 29 fields, saw 49\nSkipping line 38801: expected 29 fields, saw 52\nSkipping line 38806: expected 29 fields, saw 59\nSkipping line 38808: expected 29 fields, saw 36\nSkipping line 38812: expected 29 fields, saw 36\nSkipping line 38819: expected 29 fields, saw 37\nSkipping line 38832: expected 29 fields, saw 37\nSkipping line 38836: expected 29 fields, saw 58\nSkipping line 38839: expected 29 fields, saw 35\nSkipping line 38857: expected 29 fields, saw 38\nSkipping line 38858: expected 29 fields, saw 34\nSkipping line 38860: expected 29 fields, saw 63\nSkipping line 38864: expected 29 fields, saw 54\nSkipping line 38876: expected 29 fields, saw 51\nSkipping line 38885: expected 29 fields, saw 77\nSkipping line 38887: expected 29 fields, saw 33\nSkipping line 38894: expected 29 fields, saw 40\nSkipping line 38895: expected 29 fields, saw 30\nSkipping line 38900: expected 29 fields, saw 30\nSkipping line 38909: expected 29 fields, saw 70\nSkipping line 38915: expected 29 fields, saw 50\nSkipping line 38921: expected 29 fields, saw 59\nSkipping line 38944: expected 29 fields, saw 64\nSkipping line 38952: expected 29 fields, saw 64\nSkipping line 38957: expected 29 fields, saw 51\nSkipping line 38961: expected 29 fields, saw 52\nSkipping line 38973: expected 29 fields, saw 52\nSkipping line 38979: expected 29 fields, saw 39\nSkipping line 38985: expected 29 fields, saw 44\nSkipping line 38986: expected 29 fields, saw 56\nSkipping line 38989: expected 29 fields, saw 63\nSkipping line 38990: expected 29 fields, saw 33\nSkipping line 38994: expected 29 fields, saw 34\nSkipping line 38996: expected 29 fields, saw 42\nSkipping line 38997: expected 29 fields, saw 79\nSkipping line 39005: expected 29 fields, saw 30\nSkipping line 39009: expected 29 fields, saw 30\nSkipping line 39016: expected 29 fields, saw 45\nSkipping line 39017: expected 29 fields, saw 141\nSkipping line 39024: expected 29 fields, saw 31\nSkipping line 39026: expected 29 fields, saw 31\nSkipping line 39029: expected 29 fields, saw 34\nSkipping line 39036: expected 29 fields, saw 39\nSkipping line 39038: expected 29 fields, saw 47\nSkipping line 39039: expected 29 fields, saw 63\nSkipping line 39043: expected 29 fields, saw 64\nSkipping line 39045: expected 29 fields, saw 35\nSkipping line 39050: expected 29 fields, saw 129\nSkipping line 39060: expected 29 fields, saw 43\nSkipping line 39061: expected 29 fields, saw 45\nSkipping line 39064: expected 29 fields, saw 54\nSkipping line 39068: expected 29 fields, saw 34\nSkipping line 39071: expected 29 fields, saw 61\nSkipping line 39079: expected 29 fields, saw 38\nSkipping line 39085: expected 29 fields, saw 62\nSkipping line 39089: expected 29 fields, saw 76\nSkipping line 39091: expected 29 fields, saw 33\nSkipping line 39096: expected 29 fields, saw 40\nSkipping line 39107: expected 29 fields, saw 62\nSkipping line 39108: expected 29 fields, saw 47\nSkipping line 39115: expected 29 fields, saw 43\nSkipping line 39129: expected 29 fields, saw 61\nSkipping line 39130: expected 29 fields, saw 34\nSkipping line 39132: expected 29 fields, saw 59\nSkipping line 39135: expected 29 fields, saw 52\nSkipping line 39140: expected 29 fields, saw 59\nSkipping line 39143: expected 29 fields, saw 34\nSkipping line 39146: expected 29 fields, saw 35\nSkipping line 39147: expected 29 fields, saw 38\nSkipping line 39156: expec ...
# b'Skipping line 80475: expected 29 fields, saw 84\nSkipping line 80476: expected 29 fields, saw 120\nSkipping line 80482: expected 29 fields, saw 44\nSkipping line 80499: expected 29 fields, saw 84\nSkipping line 80517: expected 29 fields, saw 30\nSkipping line 80521: expected 29 fields, saw 34\nSkipping line 80523: expected 29 fields, saw 34\nSkipping line 80530: expected 29 fields, saw 36\nSkipping line 80534: expected 29 fields, saw 60\nSkipping line 80536: expected 29 fields, saw 35\nSkipping line 80537: expected 29 fields, saw 41\nSkipping line 80542: expected 29 fields, saw 94\nSkipping line 80543: expected 29 fields, saw 47\nSkipping line 80544: expected 29 fields, saw 49\nSkipping line 80549: expected 29 fields, saw 50\nSkipping line 80551: expected 29 fields, saw 32\nSkipping line 80554: expected 29 fields, saw 32\nSkipping line 80560: expected 29 fields, saw 75\nSkipping line 80561: expected 29 fields, saw 33\nSkipping line 80569: expected 29 fields, saw 46\nSkipping line 80571: expected 29 fields, saw 87\nSkipping line 80572: expected 29 fields, saw 38\nSkipping line 80577: expected 29 fields, saw 62\nSkipping line 80588: expected 29 fields, saw 33\nSkipping line 80592: expected 29 fields, saw 45\nSkipping line 80594: expected 29 fields, saw 30\nSkipping line 80601: expected 29 fields, saw 32\nSkipping line 80603: expected 29 fields, saw 33\nSkipping line 80610: expected 29 fields, saw 86\nSkipping line 80612: expected 29 fields, saw 56\nSkipping line 80615: expected 29 fields, saw 54\nSkipping line 80616: expected 29 fields, saw 67\nSkipping line 80617: expected 29 fields, saw 69\nSkipping line 80621: expected 29 fields, saw 36\nSkipping line 80623: expected 29 fields, saw 66\nSkipping line 80630: expected 29 fields, saw 34\nSkipping line 80635: expected 29 fields, saw 65\nSkipping line 80636: expected 29 fields, saw 32\nSkipping line 80638: expected 29 fields, saw 45\nSkipping line 80640: expected 29 fields, saw 32\nSkipping line 80655: expected 29 fields, saw 33\nSkipping line 80656: expected 29 fields, saw 71\nSkipping line 80657: expected 29 fields, saw 64\nSkipping line 80662: expected 29 fields, saw 32\nSkipping line 80663: expected 29 fields, saw 60\nSkipping line 80669: expected 29 fields, saw 44\nSkipping line 80673: expected 29 fields, saw 33\nSkipping line 80676: expected 29 fields, saw 41\nSkipping line 80686: expected 29 fields, saw 42\nSkipping line 80705: expected 29 fields, saw 64\nSkipping line 80711: expected 29 fields, saw 56\nSkipping line 80720: expected 29 fields, saw 116\nSkipping line 80721: expected 29 fields, saw 38\nSkipping line 80734: expected 29 fields, saw 144\nSkipping line 80735: expected 29 fields, saw 80\nSkipping line 80736: expected 29 fields, saw 40\nSkipping line 80740: expected 29 fields, saw 41\nSkipping line 80741: expected 29 fields, saw 31\nSkipping line 80743: expected 29 fields, saw 40\nSkipping line 80745: expected 29 fields, saw 37\nSkipping line 80746: expected 29 fields, saw 71\nSkipping line 80748: expected 29 fields, saw 93\nSkipping line 80749: expected 29 fields, saw 72\nSkipping line 80752: expected 29 fields, saw 209\nSkipping line 80770: expected 29 fields, saw 43\nSkipping line 80772: expected 29 fields, saw 41\nSkipping line 80783: expected 29 fields, saw 66\nSkipping line 80787: expected 29 fields, saw 30\nSkipping line 80791: expected 29 fields, saw 38\nSkipping line 80793: expected 29 fields, saw 34\nSkipping line 80795: expected 29 fields, saw 49\nSkipping line 80796: expected 29 fields, saw 51\nSkipping line 80797: expected 29 fields, saw 33\nSkipping line 80800: expected 29 fields, saw 35\nSkipping line 80813: expected 29 fields, saw 35\nSkipping line 80814: expected 29 fields, saw 37\nSkipping line 80816: expected 29 fields, saw 33\nSkipping line 80822: expected 29 fields, saw 54\nSkipping line 80835: expected 29 fields, saw 64\nSkipping line 80837: expected 29 fields, saw 107\nSkipping line 80844: expected 29 fields, saw 40\nSkipping line 80845: exp ...
# b'Skipping line 120155: expected 29 fields, saw 44\nSkipping line 120156: expected 29 fields, saw 53\nSkipping line 120166: expected 29 fields, saw 38\nSkipping line 120168: expected 29 fields, saw 47\nSkipping line 120171: expected 29 fields, saw 44\nSkipping line 120173: expected 29 fields, saw 39\nSkipping line 120174: expected 29 fields, saw 54\nSkipping line 120177: expected 29 fields, saw 55\nSkipping line 120180: expected 29 fields, saw 49\nSkipping line 120196: expected 29 fields, saw 35\nSkipping line 120198: expected 29 fields, saw 41\nSkipping line 120201: expected 29 fields, saw 69\nSkipping line 120205: expected 29 fields, saw 37\nSkipping line 120217: expected 29 fields, saw 33\nSkipping line 120224: expected 29 fields, saw 49\nSkipping line 120250: expected 29 fields, saw 33\nSkipping line 120259: expected 29 fields, saw 49\nSkipping line 120261: expected 29 fields, saw 31\nSkipping line 120264: expected 29 fields, saw 54\nSkipping line 120265: expected 29 fields, saw 39\nSkipping line 120266: expected 29 fields, saw 39\nSkipping line 120272: expected 29 fields, saw 50\nSkipping line 120273: expected 29 fields, saw 30\nSkipping line 120277: expected 29 fields, saw 39\nSkipping line 120279: expected 29 fields, saw 54\nSkipping line 120281: expected 29 fields, saw 35\nSkipping line 120302: expected 29 fields, saw 54\nSkipping line 120304: expected 29 fields, saw 42\nSkipping line 120310: expected 29 fields, saw 54\nSkipping line 120318: expected 29 fields, saw 37\nSkipping line 120337: expected 29 fields, saw 45\nSkipping line 120341: expected 29 fields, saw 39\nSkipping line 120342: expected 29 fields, saw 43\nSkipping line 120346: expected 29 fields, saw 33\nSkipping line 120352: expected 29 fields, saw 32\nSkipping line 120353: expected 29 fields, saw 418\nSkipping line 120354: expected 29 fields, saw 30\nSkipping line 120360: expected 29 fields, saw 61\nSkipping line 120367: expected 29 fields, saw 32\nSkipping line 120406: expected 29 fields, saw 35\nSkipping line 120419: expected 29 fields, saw 41\nSkipping line 120423: expected 29 fields, saw 34\nSkipping line 120426: expected 29 fields, saw 35\nSkipping line 120436: expected 29 fields, saw 61\nSkipping line 120437: expected 29 fields, saw 34\nSkipping line 120444: expected 29 fields, saw 45\nSkipping line 120448: expected 29 fields, saw 32\nSkipping line 120449: expected 29 fields, saw 34\nSkipping line 120456: expected 29 fields, saw 46\nSkipping line 120465: expected 29 fields, saw 54\nSkipping line 120467: expected 29 fields, saw 30\nSkipping line 120471: expected 29 fields, saw 33\nSkipping line 120475: expected 29 fields, saw 47\nSkipping line 120483: expected 29 fields, saw 72\nSkipping line 120485: expected 29 fields, saw 42\nSkipping line 120486: expected 29 fields, saw 55\nSkipping line 120498: expected 29 fields, saw 35\nSkipping line 120509: expected 29 fields, saw 32\nSkipping line 120517: expected 29 fields, saw 30\nSkipping line 120518: expected 29 fields, saw 52\nSkipping line 120525: expected 29 fields, saw 87\nSkipping line 120529: expected 29 fields, saw 46\nSkipping line 120532: expected 29 fields, saw 54\nSkipping line 120534: expected 29 fields, saw 44\nSkipping line 120535: expected 29 fields, saw 35\nSkipping line 120536: expected 29 fields, saw 80\nSkipping line 120544: expected 29 fields, saw 32\nSkipping line 120551: expected 29 fields, saw 38\nSkipping line 120561: expected 29 fields, saw 64\nSkipping line 120562: expected 29 fields, saw 33\nSkipping line 120564: expected 29 fields, saw 40\nSkipping line 120570: expected 29 fields, saw 44\nSkipping line 120572: expected 29 fields, saw 33\nSkipping line 120573: expected 29 fields, saw 48\nSkipping line 120578: expected 29 fields, saw 30\nSkipping line 120582: expected 29 fields, saw 42\nSkipping line 120605: expected 29 fields, saw 48\nSkipping line 120608: expected 29 fields, saw 32\nSkipping line 120613: expected 29 fields, saw 30\nSkipping line 120615: expected 29 fields, saw 5 ...
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = pd.DataFrame(df)

# %%
df.columns
# Out:
# Index(['id', 'workId', 'reviewId', 'workName', 'postTime', 'episodesSeen',
#        'author', 'peopleFoundUseful', 'overallRating', 'storyRating',
#        'animationRating', 'soundRating', 'characterRating', 'enjoymentRating',
#        'review'],
#       dtype='object')

# %%
nRowsRead = 'None' # specify 'None' if want to read whole file
# animeReviewsOrderByTime.csv has 135201 rows in reality, but we are only loading/previewing the first 1000 rows

with open('/Users/shiyipeng/Downloads/myanimelist-comment-dataset/animeReviewsOrderByTime.csv', 'r', encoding='utf-8') as f:
    headers = f.readline().replace('"','').replace('\n','').split(',')
    print(headers)
    print('The number of column: ', len(headers))
    dataFormat = dict()
    for header in headers:
        dataFormat[header] = list()

    for idx, line in enumerate(tqdm(f.readlines(), desc='Now parsing... ')):
        
        if idx == 67:
            yee = line
        
        if line != '':
            line = line.replace('\n','')
            indices = [i for i, x in enumerate(line) if x == ',']
            idxStart = 0
            for i in range(len(headers)):
                if i < len(headers) - 1:
                    dataFormat[headers[i]].append(line[idxStart + 1:indices[i] - 1])
                    idxStart = indices[i] + 1
                elif i == len(headers) - 1:
                    dataFormat[headers[i]].append(line[idxStart + 1:-1])
                else:
                    break
        if nRowsRead is not None and nRowsRead == idx + 1:
            print('We read only', nRowsRead, 'lines.')
            break
# Out:
# ['id', 'workId', 'reviewId', 'workName', 'postTime', 'episodesSeen', 'author', 'peopleFoundUseful', 'overallRating', 'storyRating', 'animationRating', 'soundRating', 'characterRating', 'enjoymentRating', 'review']
# The number of column:  15
# HBox(children=(FloatProgress(value=0.0, description='Now parsing... ', max=135206.0, style=ProgressStyle(descr…

# %%
review_df = pd.DataFrame(dataFormat)
review_df = review_df.iloc[0:15000,:]

# %%
review_df.head()
# Out:
#       id workId reviewId              workName             postTime  \
# 0   8121      1        1          Cowboy_Bebop  2006-11-07 18:34:00
# 1  63480    856        9         Utawarerumono  2006-11-08 00:24:00
# 2   8452    263       10        Hajime_no_Ippo  2006-11-08 14:39:00
# 3  66544    129       11  Gensoumaden_Saiyuuki  2006-11-09 05:22:00
# 4  55936    210       12               Ranma_½  2006-11-09 16:48:00
#
#   episodesSeen         author peopleFoundUseful overallRating storyRating  \
# 0           26          Xinil               162            10           8
# 1           26        Crystal               218             8           8
# 2           76          Xinil               827            10          10
# 3           50         Chelle                69             9           8
# 4          161  running_lemon                40             7           6
#
#   animationRating soundRating characterRating enjoymentRating  \
# 0              10          10              10              10
# 1               7           7               9               8
# 2               9           9              10              10
# 3               6           7              10               9
# 4               8           8               8               7
#
#                                               review
# 0  Cowboy Bebop is an episodic series. By episodi...
# 1  Utawarerumono manages to be one of those harem...
# 2  First, let me say that I\\'m not a fan of boxi...
# 3  Saiyuki is one of those animes that just grabs...
# 4  A comedy/romance based on the manga by Rumiko ...

# %%
review_df.to_csv("reviewCSV.csv")

# %%
print(len(review_df))
# Out:
# 5000

# %%
 review_df['tokenized_sents'] = review_df['review'].apply(lambda x:[lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x) if s not in stop_words ])

# %%
review_df['normalized_sents'] = review_df['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s, lemma=False) for s in x])

# %%
review_df[:100:10]
# Out:
#         id workId reviewId                                 workName  \
# 0     8121      1        1                             Cowboy_Bebop
# 10  101808    751       18                        Bomberman_Jetters
# 20  116762    133       30                              Green_Green
# 30   27052    853       40                   Ouran_Koukou_Host_Club
# 40   53443    317       56       Final_Fantasy_VII__Advent_Children
# 50   46396     85       75                  Mobile_Suit_Zeta_Gundam
# 60   53465    317       90       Final_Fantasy_VII__Advent_Children
# 70   60854     87      109  Mobile_Suit_Gundam__Chars_Counterattack
# 80  102434   1568      123  Sumomomo_Momomo__Chijou_Saikyou_no_Yome
# 90   90100    390      135                                   Suzuka
#
#                postTime episodesSeen      author peopleFoundUseful  \
# 0   2006-11-07 18:34:00           26       Xinil               162
# 10  2006-11-13 15:44:00           52  AngelIvory                11
# 20  2006-11-24 09:45:00           12     martino               150
# 30  2006-12-24 09:54:00           26       Xinil               174
# 40  2007-01-08 00:02:00            1       Ceray               101
# 50  2007-01-21 14:33:00           50  OtakuFreak                20
# 60  2007-01-25 20:57:00            1   ivorykeys                 7
# 70  2007-02-01 15:08:00            1  OtakuFreak                22
# 80  2007-02-05 17:23:00               bettynoire                72
# 90  2007-02-07 21:48:00           26     rusette               182
#
#    overallRating storyRating animationRating soundRating characterRating  \
# 0             10           8              10          10              10
# 10             9           9               9           7               7
# 20             8           6               8           9               8
# 30             8           8               9           8              10
# 40             9           8              10           9               9
# 50            10          10               8           9              10
# 60            10          10              10          10               9
# 70             9           9              10           9              10
# 80             9           8               7           8              10
# 90             8           8               8           8               9
#
#    enjoymentRating                                             review  \
# 0               10  Cowboy Bebop is an episodic series. By episodi...
# 10               9  Bomberman, if you liked the game then you will...
# 20               8  ===Animation===Quite nice and steady animation...
# 30               9  Looking for a show to laugh your ass off? Look...
# 40               9  There aren't many video game players that I kn...
# 50               8  After I became addicted to the Gundam universe...
# 60              10  FFVII Advent Children....WOW! What a fantastic...
# 70               9  Another of the UC Gundam seires is in review. ...
# 80              10  The thing about Sumomo mo Momo mo is that for ...
# 90               7  I have to say after seeing the whole series ev...
#
#                                       tokenized_sents  \
# 0   [[Cowboy, Bebop, is, an, episodic, series], [B...
# 10  [[Bomberman, if, you, liked, the, game, then, ...
# 20  [[=, =, =, Animation===Quite], [nice, and, ste...
# 30  [[Looking, for, a, show, to, laugh, your, ass,...
# 40  [[There, are, n't, many, video, game, players,...
# 50  [[After, I, became, addicted, to, the, Gundam,...
# 60  [[FFVII, Advent, Children], [WOW], [What, a, f...
# 70  [[Another, of, the, UC, Gundam, seires, is, in...
# 80  [[The, thing, about, Sumomo, mo, Momo, mo, is,...
# 90  [[I, have, to, say, after, seeing, the, whole,...
#
#                                      normalized_sents
# 0   [[cowboy, bebop, episodic, series], [episodic,...
# 10  [[bomberman, liked, game, like, anime], [think...
# 20  [[=, =, =, animation===quite], [nice, steady, ...
# 30  [[looking, laugh, ass], [look, ouran, high, sc...
# 40  [[video, game, players, know, heard, final, fa...
# 50  [[addicted, gundam, universe, series, dying, m...
# 60  [[ffvii, advent, children], [wow], [fantastic,...
# 70  [[uc, gundam, seires, review], [introduced, gu...
# 80  [[thing, sumomo, mo, momo, mo, episodes, convi...
# 90  [[seeing, series, lot, people, said, sucked], ...

# %%
reviewW2V = gensim.models.word2vec.Word2Vec(review_df['normalized_sents'].sum())
reviewW2V['people']
# Out:
# array([ 1.1038873 , -0.176359  ,  0.3480285 ,  0.29849905,  0.6096195 ,
#         1.1159438 , -0.21845603, -0.31832272, -1.3199272 , -0.92404616,
#         1.0668259 ,  1.5050788 , -0.39584342, -0.59719455, -1.3599824 ,
#         1.5373003 , -2.2474892 , -0.7090683 ,  0.80336237, -0.24457563,
#        -0.427895  , -0.9251555 ,  1.259764  , -0.6768172 , -1.3625624 ,
#         0.61188287,  0.12880976,  0.95788676, -0.30775493, -1.1211289 ,
#        -0.20990275,  1.0304292 , -0.50764084, -0.6213444 ,  0.1859648 ,
#         1.1970522 ,  0.36244866,  1.5232556 ,  1.1139876 , -0.34309202,
#        -0.05658117,  0.2594782 ,  0.9109661 ,  0.893326  ,  1.5016395 ,
#         0.9016543 , -0.32180706, -1.0528514 , -0.260168  , -0.6107211 ,
#         0.46237415, -0.38485023, -2.004648  ,  0.7382373 ,  1.0755956 ,
#         0.42119437,  0.8266001 , -1.4009106 ,  0.24803291, -0.3476314 ,
#         0.26477072, -0.21505556, -0.965719  ,  0.595706  , -1.4477642 ,
#        -0.34339258,  1.6323596 , -0.20824228, -0.7189581 ,  1.2529516 ,
#         0.6504642 , -1.7822967 , -0.6460004 ,  0.01251367, -3.1291523 ,
#        -1.0026814 , -0.8205311 ,  0.18591402, -1.0475172 ,  0.02141988,
#         0.30510592,  1.3518865 ,  0.0461081 ,  0.24661094, -1.9707997 ,
#         0.6367781 ,  0.7263003 , -1.3357018 , -1.0353942 ,  0.48289797,
#         0.2590735 , -1.3798343 , -0.12859415, -0.29491997,  0.8155545 ,
#        -0.7604645 , -0.28021866, -0.9873285 , -0.19573005, -0.2668686 ],
#       dtype=float32)

# %%
reviewW2V_sg = gensim.models.word2vec.Word2Vec(review_df['normalized_sents'].sum(),sg=0)

# %%
reviewW2V_sg.wv.syn0
# Out:
# array([[ 0.12814385, -0.65448374,  0.26498452, ..., -0.6477126 ,
#         -0.8901765 ,  0.5011775 ],
#        [ 0.04619661, -0.20310569, -0.3687164 , ..., -0.6346404 ,
#         -0.2807196 ,  0.72473663],
#        [ 0.3581876 , -1.0563473 ,  0.60413474, ...,  0.5866377 ,
#         -0.32497555, -0.13061444],
#        ...,
#        [ 0.12456775, -0.02896465,  0.02687157, ..., -0.05805482,
#         -0.00267247, -0.00715161],
#        [ 0.07098372, -0.01541638,  0.01765821, ..., -0.01761384,
#         -0.02232168,  0.01328673],
#        [ 0.10004701, -0.00419356,  0.03140612, ..., -0.00708884,
#          0.00164382, -0.02742243]], dtype=float32)

# %%
reviewW2V_sg.doesnt_match(
['cowboy', 'crush', 'magical',
 'tale', 'adventure'])
# Out:
# 'cowboy'

# %%
reviewW2V_sg.doesnt_match(
['cowboy','crush','magical',
'tale','adventrue'])
# Out:
# 'cowboy'

# %%
def cosine_distance (model, word,target_list , num) :
    cosine_dict ={}
    word_list = []
    a = model[word]
    for item in target_list :
        if item != word :
            b = model [item]
            cos_sim = dot(a, b)/(norm(a)*norm(b))
            cosine_dict[item] = cos_sim
    dist_sort=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True) ## in Descedning order 
    for item in dist_sort:
        word_list.append((item[0], item[1]))
    return word_list[0:num]

# %%
review_df['normalized_words']
words = []
for each in review_df['normalized_words']:
    for i in each:
        if "\\" in i:
            continue
        if i.isdigit() == False:
            words.append(i)
words
# Out:
# ['cowboy',
#  'bebop',
#  'episodic',
#  'series',
#  'episodic',
#  'mean',
#  'episode',
#  'necessarily',
#  'lead',
#  'follow',
#  'said',
#  'expect',
#  'lot',
#  'series',
#  'watch',
#  'cowboy',
#  'bebop',
#  'characters',
#  'plain',
#  'simple',
#  'spike',
#  'faye',
#  'jet',
#  'ed',
#  'ein',
#  'anime',
#  'arguably',
#  'memorable',
#  'series',
#  'produced',
#  'music',
#  'awesome',
#  'especially',
#  'fan',
#  'jazz',
#  'animation',
#  'notch',
#  'considering',
#  'series',
#  'came',
#  'enjoyment',
#  'value',
#  'second',
#  'lot',
#  'people',
#  'want',
#  'feel',
#  'kind',
#  'person',
#  'enjoys',
#  'fast',
#  'paced',
#  'anime',
#  'character',
#  'getting',
#  'spotlight',
#  'type',
#  'enjoy',
#  'fast',
#  'paced',
#  'bounty',
#  'huntin',
#  'fun',
#  'like',
#  'deep',
#  'thought',
#  'provoking',
#  'dark',
#  'mysterious',
#  'shows',
#  'watch',
#  'cowboy',
#  'bebop',
#  'vicious',
#  'characters',
#  'able',
#  'bring',
#  'little',
#  'sinister',
#  'kind',
#  'utawarerumono',
#  'manages',
#  'harem',
#  'animes',
#  'possibly',
#  'find',
#  'enjoyable',
#  'particularly',
#  'like',
#  'concept',
#  'harems',
#  'based',
#  'ero',
#  'game',
#  'title',
#  'utawarerumono',
#  'focuses',
#  'amnesiac',
#  'man',
#  'found',
#  'critically',
#  'injured',
#  'rural',
#  'village',
#  'kindness',
#  'villagers',
#  'recovers',
#  'spends',
#  'days',
#  'peacefully',
#  'peaceful',
#  'times',
#  'quickly',
#  'end',
#  'heart',
#  'shattering',
#  'event',
#  'throws',
#  'man',
#  'fellow',
#  'villagers',
#  'life',
#  'war',
#  'storythe',
#  'story',
#  'utawarerumono',
#  'somewhat',
#  'simplistic',
#  'majority',
#  'anime',
#  'following',
#  'simple',
#  'formula',
#  'battles',
#  'battles',
#  'battles',
#  'introducing',
#  'new',
#  'characters',
#  'find',
#  'way',
#  'story',
#  'unfolds',
#  'repetitive',
#  'fan',
#  'war',
#  'stories',
#  'occasionally',
#  'comedic',
#  'situations',
#  'intelligent',
#  'strategies',
#  'undermine',
#  'enemy',
#  'likely',
#  'overlook',
#  'lack',
#  'variation',
#  'despite',
#  'said',
#  'utawarerumono',
#  'number',
#  'twists',
#  'turns',
#  'especially',
#  'second',
#  'half',
#  'viewer',
#  'glued',
#  'chairs',
#  'long',
#  'story',
#  'animationanimation',
#  'positive',
#  'negative',
#  'point',
#  'utawarerumono',
#  'animation',
#  'actually',
#  'animates',
#  'characters',
#  'combat',
#  'compared',
#  'anime',
#  'use',
#  'images',
#  'lines',
#  'indicate',
#  'action',
#  'good',
#  'detail',
#  'recycled',
#  'animation',
#  'occurs',
#  'reused',
#  'animation',
#  'unfortunately',
#  'noticeable',
#  'frequent',
#  'detract',
#  'enjoyment',
#  'battles',
#  'cg',
#  'animation',
#  'present',
#  'mixed',
#  'bag',
#  'like',
#  'way',
#  'cg',
#  'occasionally',
#  'huge',
#  'issue',
#  'character',
#  'designs',
#  'consistent',
#  'detailed',
#  'interesting',
#  'albeit',
#  'episode(s',
#  'characters',
#  'looking',
#  'slightly',
#  'odd',
#  'usual',
#  'different',
#  'animators',
#  'soundsound',
#  'mixed',
#  'bag',
#  'like',
#  'hate',
#  'opening',
#  'song',
#  'catchy',
#  'particularly',
#  'memorable',
#  'ending',
#  'song',
#  'proves',
#  'unique',
#  'flair',
#  'overall',
#  'tone',
#  'music',
#  'befitting',
#  'ambiance',
#  'anime',
#  'utawarerumono',
#  'contains',
#  'number',
#  'battle',
#  'scenes',
#  'background',
#  'music',
#  'giving',
#  'proper',
#  'mood',
#  'needed',
#  'set',
#  'atmosphere',
#  'voice',
#  'acting',
#  'decent',
#  'standing',
#  'befitting',
#  'character',
#  'characterutawarerumono',
#  'harem',
#  'anime',
#  'contains',
#  'usual',
#  'female',
#  'stock',
#  'characters',
#  'find',
#  'harems',
#  'flirtatious',
#  'cute',
#  'shy',
#  'etc',
#  'majority',
#  'focusing',
#  'war',
#  'thankfully',
#  'female',
#  'characters',
#  'harem',
#  'play',
#  'role',
#  'story',
#  'character',
#  'developed',
#  'likely',
#  'time',
#  'constraints',
#  'm',
#  'sure',
#  'original',
#  'game',
#  'developed',
#  'ones',
#  'missed',
#  'thankfully',
#  'main',
#  'character',
#  'number',
#  'major',
#  'characters',
#  'given',
#  'development',
#  'time',
#  'flesh',
#  'backgrounds',
#  'enjoymentas',
#  'enjoyed',
#  'utawarerumono',
#  'natural',
#  'bias',
#  'considered',
#  'harem',
#  'anime',
#  'nicely',
#  'animated',
#  'action',
#  'scenes',
#  'character',
#  'designs',
#  'won',
#  'series',
#  'storywise',
#  'thought',
#  'offer',
#  'suprised',
#  'second',
#  'half',
#  'number',
#  'twists',
#  'thrown',
#  'making',
#  'overall',
#  'story',
#  'anime',
#  'interesting',
#  'found',
#  'characters',
#  'likeable',
#  'certain',
#  'obviously',
#  'meant',
#  'hated',
#  'viewers',
#  'wish',
#  'characters',
#  'ones',
#  'given',
#  'time',
#  'developed',
#  'properly',
#  'overalloverall',
#  'utawarerumono',
#  'manages',
#  'deliver',
#  'enjoyable',
#  'package',
#  'casual',
#  'anime',
#  'viewer',
#  'desire',
#  'watch',
#  'presence',
#  'foreshadowing',
#  'good',
#  'background',
#  'story',
#  'told',
#  'different',
#  'episodes',
#  'way',
#  'utawarerumono',
#  'little',
#  'bit',
#  'fan',
#  'service',
#  'like',
#  'scenes',
#  'characters',
#  'large',
#  'intense',
#  'action',
#  'scenes',
#  'intriguing',
#  'somewhat',
#  'deep',
#  'plot',
#  'seeking',
#  'mindless',
#  'profound',
#  'prove',
#  'strong',
#  'given',
#  'area',
#  'delivers',
#  'leave',
#  'anime',
#  'fans',
#  'somewhat',
#  'satisfied',
#  've',
#  'seen',
#  'let',
#  'fan',
#  'boxing',
#  'fact',
#  'pretty',
#  'hate',
#  'sport',
#  'honestly',
#  'likes',
#  'seeing',
#  'people',
#  'getting',
#  'head',
#  'beat',
#  'day?with',
#  'said',
#  'series',
#  'brilliantly',
#  'comedy',
#  'romance',
#  'plenty',
#  'plenty',
#  'plenty',
#  'plot',
#  'follow',
#  'ippo',
#  'grows',
#  'person',
#  'professional',
#  'boxer',
#  'laugh',
#  'probably',
#  'cry',
#  'fact',
#  'like',
#  'boxing',
#  'came',
#  'play',
#  'probably',
#  'find',
#  'jabs',
#  'watching',
#  'captivating',
#  'supporting',
#  'characters',
#  'awesome',
#  'takamura',
#  'kimura',
#  'aoki',
#  'equally',
#  'hilarious',
#  'distinct',
#  'personality',
#  'lovable',
#  'support',
#  'ippo',
#  'meets',
#  'trials',
#  'boxing',
#  'life',
#  'definitely',
#  'series',
#  'try',
#  'disappointed',
#  'episodes',
#  'fact',
#  'probably',
#  'end',
#  'reading',
#  'manga',
#  'want',
#  'stop',
#  'saiyuki',
#  'animes',
#  'grabs',
#  'episode',
#  'wo',
#  'let',
#  'episodic',
#  'anime',
#  'storylines',
#  'episodes',
#  'tell',
#  'follow',
#  'travelers',
#  'sent',
#  'gods',
#  'prevent',
#  'reawakening',
#  'old',
#  'extremely',
#  'dangerous',
#  'demon',
#  'complaint',
#  'anime',
#  'animation',
#  'lot',
#  'battle',
#  'scenes',
#  'overlook',
#  'animation',
#  'clean',
#  'like',
#  'think',
#  'maybe',
#  'intended',
#  'way',
#  'story',
#  'characters',
#  'perfect',
#  'better',
#  'sanzo',
#  'renegade',
#  'priest',
#  'swears',
#  'smokes',
#  'drinks',
#  'weilds',
#  'banishing',
#  'gun',
#  'tongue',
#  'sharp',
#  'razor',
#  'goku',
#  'lovable',
#  'little',
#  'monkey',
#  'king',
#  'hungry',
#  'whiny',
#  'kicks',
#  'butt',
#  'battles',
#  'hakkai',
#  'soft',
#  'spoken',
#  'sympathetic',
#  'demon',
#  'heart',
#  'gold',
#  'tragic',
#  'past',
#  'finally',
#  'personal',
#  'favorite',
#  'gojyo',
#  'drinking',
#  'gambling',
#  'swearing',
#  'skirt',
#  'chasing',
#  'pervert',
#  'water',
#  'sprite',
#  'makes',
#  'laugh',
#  'loud',
#  'everytime',
#  'opens',
#  'mouth',
#  'characters',
#  'tragic',
#  'past',
#  'hakkai',
#  'probably',
#  'worst',
#  'revisited',
#  'time',
#  'time',
#  'help',
#  'understand',
#  'way',
#  'music',
#  'anime',
#  'great',
#  'especially',
#  'op',
#  'songs',
#  'actually',
#  'buy',
#  'ost',
#  'find',
#  'goal',
#  'entire',
#  'series',
#  'prevent',
#  'resurrection',
#  'old',
#  'demon',
#  'entire',
#  'series',
#  'works',
#  'goal',
#  'basically',
#  'episodic',
#  'anime',
#  'enjoy',
#  '^_^',
#  'comedy',
#  'romance',
#  'based',
#  'manga',
#  'rumiko',
#  'takahashi',
#  'ranma',
#  'revolves',
#  'arranged',
#  'marriage',
#  'ranma',
#  'saotome',
#  'boy',
#  'trained',
#  'father',
#  'martial',
#  'arts',
#  'childhood',
#  'akane',
#  'tendo',
#  'average',
#  'girl',
#  'martial',
#  'artist',
#  'living',
#  'father',
#  'sisters',
#  'relationship',
#  'starts',
#  'rocky',
#  'time',
#  'begin',
#  'grow',
#  'close',
#  'complications',
#  'brought',
#  'characters',
#  'story',
#  'premise',
#  'ranma',
#  'makes',
#  'unique',
#  'comedy',
#  'romance',
#  'anime',
#  'jusenkyo',
#  'springs',
#  'fallen',
#  'cause',
#  'person',
#  'cursed',
#  'ranma',
#  'cursed',
#  'turns',
#  'girl',
#  'splashed',
#  'cold',
#  'water',
#  'changed',
#  'boy',
#  'splashed',
#  'warm',
#  'water',
#  'story',
#  'focuses',
#  'love',
#  'webs',
#  'numerous',
#  'characters',
#  'love',
#  'ranma',
#  'akane',
#  'leads',
#  'conflicts',
#  'usually',
#  'resolved',
#  'martial',
#  'arts',
#  'supernatural',
#  'elements',
#  'seasons',
#  'introduce',
#  'new',
#  'characters',
#  'elements',
#  'stale',
#  'repetitive',
#  'fail',
#  'rap',
#  'plotlines',
#  'drastically',
#  'changed',
#  'season',
#  'season',
#  'animation',
#  'hard',
#  'comment',
#  'animation',
#  'anime',
#  'late',
#  'early',
#  'time',
#  'character',
#  'appearence',
#  'consistant',
#  'fighting',
#  'scenes',
#  'like',
#  'said',
#  'time',
#  'instances',
#  'come',
#  'little',
#  'choppy',
#  'recycled',
#  'animation',
#  'sound',
#  'sound',
#  'fitting',
#  'tone',
#  'music',
#  'battles',
#  'scenes',
#  'come',
#  'silly',
#  'time',
#  'battles',
#  'opening',
#  'ending',
#  'fit',
#  'enjoyable',
#  'watched',
#  'japanese',
#  'voice',
#  'acting',
#  'average',
#  'gets',
#  'extra',
#  'points',
#  'having',
#  'great',
#  'kappei',
#  'yamaguchi',
#  'male',
#  'ranma',
#  'megumi',
#  'hayashibara',
#  'female',
#  'ranma',
#  'character',
#  'anime',
#  'feature',
#  'characters',
#  'alot',
#  'feelings',
#  'akane',
#  'ranma',
#  'spend',
#  'alot',
#  'time',
#  'trying',
#  'wedge',
#  'apart',
#  'win',
#  'favor',
#  'love',
#  'like',
#  'ranma',
#  'characters',
#  'jusenkyo',
#  'curses',
#  'change',
#  'form',
#  'curses',
#  'include',
#  'cat',
#  'duck',
#  'pig',
#  'panda',
#  'minor',
#  'characters',
#  'appear',
#  'times',
#  'usually',
#  'present',
#  'type',
#  'martial',
#  'arts',
#  'supernatural',
#  'challenge',
#  'enjoyment',
#  'disapointed',
#  'way',
#  'repetitive',
#  'plot',
#  'shallow',
#  'ending',
#  'overall',
#  'enjoy',
#  'situations',
#  'humorous',
#  'personalities',
#  'alot',
#  'characters',
#  'rumiko',
#  'takahashi',
#  'fan',
#  'probably',
#  'seen',
#  'like',
#  'overly',
#  'silly',
#  'comedy',
#  'romances',
#  'bit',
#  'action',
#  'recommend',
#  'anime',
#  'traveler',
#  'journeying',
#  'different',
#  'countries',
#  'talking',
#  'motorcycle',
#  'sounds',
#  'boring',
#  'right',
#  'wrong',
#  'episodic',
#  'anime',
#  'odd',
#  'little',
#  'stories',
#  'dialogue',
#  'actually',
#  'explores',
#  'different',
#  'aspects',
#  'human',
#  'nature',
#  'unique',
#  'ways',
#  'seen',
#  'little',
#  'character',
#  'development',
#  'kind',
#  'story',
#  'need',
#  'episode',
#  'gives',
#  'story',
#  'kino',
#  'different',
#  'countries',
#  'kino',
#  'visits',
#  'people',
#  'kino',
#  'encounters',
#  'cry',
#  'enrage',
#  'times',
#  'disgust',
#  'making',
#  'run',
#  'gammit',
#  'emotions',
#  'stop',
#  'ask',
#  'episodes',
#  'great',
#  'lessons',
#  'teach',
#  'throwing',
#  'propoganda',
#  'face',
#  'preaching',
#  'animation',
#  'clean',
#  'beautiful',
#  'colors',
#  'bright',
#  'vibrant',
#  'makes',
#  'anime',
#  'little',
#  'realistic',
#  'music',
#  'beautiful',
#  'different',
#  'times',
#  'enhances',
#  'emotions',
#  'beautiful',
#  'anime',
#  'adored',
#  'anime',
#  'm',
#  'looking',
#  'forward',
#  'watching',
#  'movie',
#  'definitely',
#  'anime',
#  'lovers',
#  '^_^',
#  'kare',
#  'kano',
#  'romance',
#  'anime',
#  'incredibly',
#  'great',
#  'proper',
#  'budget',
#  'ideas',
#  'producer',
#  'actually',
#  'complete',
#  'properly',
#  'unfortunately',
#  'stale',
#  'ending',
#  'kare',
#  'kano',
#  'ended',
#  'left',
#  'm',
#  'sure',
#  'fans',
#  'frustration',
#  'based',
#  'popular',
#  'shoujo',
#  'manga',
#  'masami',
#  'tsuda',
#  'kare',
#  'kano',
#  'blossoming',
#  'love',
#  'high',
#  'school',
#  'students',
#  'lived',
#  'life',
#  'lies',
#  'pretending',
#  'perfect',
#  'person',
#  'reasons',
#  'able',
#  'truthfully',
#  'open',
#  'initial',
#  'friendship',
#  'turns',
#  'love',
#  'sadly',
#  'life',
#  'easy',
#  'face',
#  'trials',
#  'glance',
#  'kare',
#  'kano',
#  'average',
#  'high',
#  'school',
#  'romance',
#  'story',
#  'thankfully',
#  'odd',
#  'personalities',
#  'leading',
#  'characters',
#  'break',
#  'idea',
#  'romance',
#  'story',
#  'kare',
#  'kano',
#  'contain',
#  'usual',
#  'shoujo',
#  'romance',
#  'story',
#  'elements',
#  'comes',
#  'trials',
#  'main',
#  'couple',
#  ...]

# %%
reviewW2V.wv.syn0
# Out:
# array([[ 0.05951188, -0.7388488 ,  0.13702476, ..., -0.84931046,
#         -0.8986795 ,  0.3230357 ],
#        [ 0.1385944 , -0.08336248, -0.92674345, ...,  0.24038537,
#         -0.18178526,  0.51117885],
#        [ 0.32035998, -0.99359226,  0.01297696, ...,  1.014285  ,
#         -0.07044256, -0.15711258],
#        ...,
#        [ 0.10281115, -0.03042682,  0.01618071, ..., -0.01561393,
#         -0.00696898, -0.0079455 ],
#        [ 0.05661745, -0.01016468,  0.00859534, ..., -0.00875099,
#         -0.01729053,  0.01221136],
#        [ 0.0942239 , -0.01194219,  0.01671214, ...,  0.00335156,
#         -0.00358949, -0.01978069]], dtype=float32)

# %%
reviewW2V.wv.index2word[100]
# Out:
# 'shows'

# %%
reviewW2V.most_similar('horror')
# Out:
# [('screwball', 0.966116189956665),
#  ('thriller', 0.9516334533691406),
#  ('pure', 0.94920414686203),
#  ('genres', 0.9455623030662537),
#  ('enjoys', 0.9415861964225769),
#  ('junkie', 0.937781572341919),
#  ('slapstick', 0.9358917474746704),
#  ('adventure', 0.9326483607292175),
#  ('comedies', 0.9308334589004517),
#  ('romp', 0.924423098564148)]

# %%
reviewW2V.most_similar('best')
# Out:
# [('worst', 0.8400263786315918),
#  ('greatest', 0.8346506357192993),
#  ('favourite', 0.7971599698066711),
#  ('unlike', 0.7890238761901855),
#  ('saddest', 0.7611674070358276),
#  ('i&rsquo;ve', 0.7509399652481079),
#  ('funniest', 0.7505335807800293),
#  ("i\\\\'ve", 0.7461510896682739),
#  ('favorite', 0.7419319152832031),
#  ('loved', 0.7309887409210205)]

# %%
reviewW2V.most_similar('orchestra')
# Out:
# [('acoustic', 0.9848574995994568),
#  ('accompanied', 0.9838211536407471),
#  ('vocals', 0.9829440116882324),
#  ('instruments', 0.9817919135093689),
#  ('melodies', 0.9816027879714966),
#  ('soothing', 0.9815669059753418),
#  ('evocative', 0.9811508655548096),
#  ('orchestral', 0.9798853397369385),
#  ('haunting', 0.9791637659072876),
#  ('techno', 0.9784820079803467)]

# %%
reviewW2V.similarity('orchestra','cowboy')
# Out:
# 0.5780048

# %%
reviewW2V.doesnt_match(
['cowboy', 'crush', 'magical',
 'tale', 'adventure'])
# Out:
# 'cowboy'

# %%
reviewW2V.most_similar(positive=
['monster', 'giant'], negative = ['scary'])
# Out:
# [('robot', 0.9033343195915222),
#  ('space', 0.8789113163948059),
#  ('war', 0.8712047934532166),
#  ('humans', 0.8617904186248779),
#  ('monsters', 0.8595252633094788),
#  ('power', 0.8590700626373291),
#  ('living', 0.8576363325119019),
#  ('earth', 0.857327401638031),
#  ('tale', 0.8558833003044128),
#  ('secret', 0.853628396987915)]

# %%
reviewW2V.save("reviewWORD2Vec")

# %%
numWords = 100
targetWords = reviewW2V.wv.index2word[:numWords]

# %%
wordsSubMatrix = []
for word in targetWords:
    wordsSubMatrix.append(reviewW2V[word])
wordsSubMatrix = np.array(wordsSubMatrix)
wordsSubMatrix
# Out:
# array([[-0.65470284,  0.5613238 ,  0.58732736, ..., -1.4957318 ,
#         -0.31469083,  0.885352  ],
#        [-1.3246515 ,  0.07514439,  1.0957496 , ..., -0.5812275 ,
#         -0.5448955 ,  0.8602921 ],
#        [ 0.43063927, -0.79568386,  1.533702  , ...,  1.2064046 ,
#         -2.2701466 ,  1.7276573 ],
#        ...,
#        [-0.18360838,  0.81327796,  0.02060139, ..., -0.22958823,
#         -1.8506157 ,  0.86790776],
#        [-0.15451837, -0.3880261 , -1.0316975 , ..., -0.04803879,
#          1.1737674 ,  0.35441542],
#        [ 0.5380852 ,  0.99457914, -0.91829205, ...,  0.8112428 ,
#          0.56488836,  0.53658533]], dtype=float32)

# %%
pcaWords = sklearn.decomposition.PCA(n_components = 2).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#print(reducedPCA_data)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(wordsSubMatrix)
#print(tsneWords)
print(pcaWords.explained_variance_/np.sum(pcaWords.explained_variance_))
# Out:
# [0.50686204 0.49313796]

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(reducedPCA_data[:, 0], reducedPCA_data[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (reducedPCA_data[:, 0][i],reducedPCA_data[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
review_df['review'][:20]
# Out:
# 0     Cowboy Bebop is an episodic series. By episodi...
# 1     Utawarerumono manages to be one of those harem...
# 2     First, let me say that I\\'m not a fan of boxi...
# 3     Saiyuki is one of those animes that just grabs...
# 4     A comedy/romance based on the manga by Rumiko ...
# 5     What do you say about an anime that is just ab...
# 6     Kare Kano was a romance anime that could have ...
# 7     Overall:  My very best anime and i haven't act...
# 8     Overall:Honestly I really don't care about oth...
# 9     Hunters… What do you think about when you hear...
# 10    Bomberman, if you liked the game then you will...
# 11    Hate watching those anime that drag on for too...
# 12    Elfen Lied is something else. Just watching th...
# 13    ===Animation===Toei did a pretty good job with...
# 14    Love bread?  Ever wondered how they make it?  ...
# 15    Scrapped Princess is a quite interesting genre...
# 16    Slayers is a comedy/adventure/fantasy anime di...
# 17    If you'd like to see my full review than leave...
# 18    If you'd like to see my full review then leave...
# 19    If you'd like to see my full review then leave...
# Name: review, dtype: object

# %%
keywords = ['scary','blood','killing','ghost','gloomy','dark','darkness','violence','slayers','relaxing','plain','calm','soothing']

# %%
review_df['tokenized_words'] = review_df['review'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
review_df['normalized_words'] = review_df['tokenized_words'].apply(lambda x:lucem_illud_2020.normalizeTokens(x,lemma=False))

# %%
taggedDocs = []
for index, row in review_df_h.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(row['overallRating'])
    docKeywords.append(row['workName']) #This lets us extract individual documnets since doi's are unique
    taggedDocs.append(gensim.models.doc2vec.LabeledSentence(words = row['normalized_words'], tags = docKeywords))
review_df_h['TaggedAbstracts'] = taggedDocs
reviewD2V = gensim.models.doc2vec.Doc2Vec(review_df_h['TaggedAbstracts'], size = 25)
print(review_df_h['TaggedAbstracts'])
# Out:
# 0        ([cowboy, bebop, episodic, series, episodic, m...
# 1        ([utawarerumono, manages, harem, animes, possi...
# 2        ([let, i\\'m, fan, boxing, fact, pretty, hate,...
# 3        ([saiyuki, animes, grabs, episode, wo, let, ep...
# 4        ([comedy, romance, based, manga, rumiko, takah...
#                                ...
# 14995    ([story, story, edward, elric, found, eduard, ...
# 14996    ([movie, heart, warming, characters, unique, s...
# 14997    ([clannad, originally, visual, novel, pc, kyot...
# 14998    ([detail, review, wrote, manga*tamiki, wakiki,...
# 14999    ([half, movie, extremely, boring, story, time,...
# Name: TaggedAbstracts, Length: 15000, dtype: object

# %%
reviewD2V.docvecs[1000]
# Out:
# array([ 0.5521214 , -0.34660336, -0.28243974,  1.6916969 ,  0.08458388,
#        -0.6048177 , -1.5222051 ,  0.11925302, -0.24933988, -0.2329682 ,
#         0.70786196,  1.3571529 , -0.14132737,  2.111212  , -1.4084097 ,
#        -1.1868218 ,  1.2899429 ,  1.051305  , -0.02507528,  0.226507  ,
#         1.7689136 , -0.15176187,  0.26791826, -0.07456066,  0.2843357 ],
#       dtype=float32)

# %%
reviewD2V.most_similar(positive = ['japan','world'], negative = ['sakura'], topn = 1)
# Out:
# [('apocalyptic', 0.82994544506073)]

# %%
reviewD2V.most_similar(positive = ['horror','movie'], negative = ['ghost'], topn = 1)
# Out:
# [('thrills', 0.7722503542900085)]

# %%
reviewD2V.docvecs.most_similar([ reviewD2V['dark'] ], topn=5 )
# Out:
# [('darkness', 0.7192763090133667),
#  ('dark', 0.6133599281311035),
#  ('scary', 0.5979629755020142),
#  ('Gad_Guard', 0.5861226320266724),
#  ('Dirty_Pair_no_Ooshoubu__Nolandia_no_Nazo', 0.5706272125244141)]

# %%
from IPython.display import Image
reviewD2V.docvecs.most_similar([ reviewD2V.docvecs['Shining_Tears_X_Wind'] ], topn=5 )
# Out:
# [('Shining_Tears_X_Wind', 1.0),
#  ('Bleach__The_Sealed_Sword_Frenzy', 0.622992753982544),
#  ('Tokineiro', 0.6156351566314697),
#  ('Innocent_Venus', 0.6133731603622437),
#  ('Dogs__Bullets___Carnage', 0.6005896329879761)]

# %%
reviewD2V.docvecs.most_similar([ reviewD2V['magic']+reviewD2V['kid']+reviewD2V['happy']], topn=5 )
# Out:
# [('Osakana_wa_Ami_no_Naka', 0.6739438772201538),
#  ('After_The_Animation', 0.588451087474823),
#  ('Gakuen_Heaven', 0.5851773023605347),
#  ('Shounen_Maid_Kuuro-kun__Tenshi_no_Uta', 0.5711440443992615),
#  ('Nyoro-n_Churuya-san', 0.5678746700286865)]

# %%
reviewD2V.docvecs.most_similar([ reviewD2V['kill']+reviewD2V['blood']+reviewD2V['red']], topn=5 )
# Out:
# [('Baoh_Raihousha', 0.6991081237792969),
#  ('Jigen_Sengokushi__Kuro_no_Shishi_-_Jinnai-hen', 0.6945781707763672),
#  ('Grappler_Baki_TV', 0.6269474029541016),
#  ('Seikai_no_Senki_II', 0.6165720224380493),
#  ('Natural_2__Duo', 0.6151338219642639)]

# %%
reviewD2V.most_similar( [ reviewD2V.docvecs['Cowboy_Bebop']+reviewD2V.docvecs['Kino_no_Tabi__The_Beautiful_World'] ], topn=5)
# Out:
# [('tabi', 0.7374928593635559),
#  ('kino', 0.7295339107513428),
#  ('interwoven', 0.6563735604286194),
#  ('paranoia', 0.649248480796814),
#  ('mastered', 0.6410422325134277)]

# %%
keywords2 = ['Baoh_Raihousha','Natural_2__Duo','Grappler_Baki_TV']
heatmapMatrix = []
for tagOuter in keywords2:
    column = []
    tagVec = reviewD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords2:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, reviewD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrix, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords2, minor=False, rotation=270)
a = ax.set_yticklabels(keywords2, minor=False)

# %%
targetDocs = review_df_h['workName'][10:30]

heatmapMatrixD = []

for tagOuter in targetDocs:
    column = []
    tagVec = reviewD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in targetDocs:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, reviewD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixD.append(column)
heatmapMatrixD = np.array(heatmapMatrixD)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixD, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixD.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixD.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(targetDocs, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = reviewD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, reviewD2V[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
reviewD2V.save('reviewW2V')

# %%
review_df['normalized_words'][:10]
# Out:
# 0    [cowboy, bebop, episodic, series, episodic, me...
# 1    [utawarerumono, manages, harem, animes, possib...
# 2    [let, i\\'m, fan, boxing, fact, pretty, hate, ...
# 3    [saiyuki, animes, grabs, episode, wo, let, epi...
# 4    [comedy, romance, based, manga, rumiko, takaha...
# 5    [anime, traveler, journeying, different, count...
# 6    [kare, kano, romance, anime, incredibly, great...
# 7    [overall, best, anime, actually, seen, level, ...
# 8    [overall, honestly, care, opinions, anime, fun...
# 9    [hunters, think, hear, anime, people, killing,...
# Name: normalized_words, dtype: object

# %%
TargetWords = ['man','him','he', 'woman', 'her', 'she', 'killing','scary','blood','romance', 'funny', 'beautiful','highschool', 'teenager', 'young','office', 'senior', 'old','suspense','ghost','detective','relaxing','reality','police','wine','cowboy','gun','robber']
#words we will be mapping

wordsSubMatrix = []
for word in TargetWords:
    wordsSubMatrix.append(model[word])
wordsSubMatrix = np.array(wordsSubMatrix)

# %%
pcaWords = sklearn.decomposition.PCA(n_components = 22).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %%
fig = plt.figure(figsize = (20,12))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0) #Making the points invisible
for i, word in enumerate(TargetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  40 * (len(TargetWords) - i) / len(TargetWords))
plt.xticks(())
plt.yticks(())
plt.show()

# %%
def normalize(vector):
    normalized_vector = vector / np.linalg.norm(vector)
    return normalized_vector

def dimension(model, positives, negatives):
    diff = sum([normalize(model[x]) for x in positives]) - sum([normalize(model[y]) for y in negatives])
    return diff

# %%
Gender = dimension(reviewD2V, ['man'], ['woman'])
Style = dimension(reviewD2V, ['killing','scary','blood','suspense','ghost','gun'], ['romance', 'funny', 'beautiful','relaxing','reality','wine'])
Setting = dimension(reviewD2V, ['highschool', 'class', 'students'], ['office', 'workers', 'seniors'])
Job = dimension(reviewD2V,['detective','police','doctor','teacher'],['cowboy','thief','godfather','boss'])

# %%
job = ['detective','police','cowboy','thief','doctor','professor','artist','teacher','worker']
style = ['killing','scary','blood','suspense','ghost','gun','romance', 'funny', 'beautiful','relaxing','reality','violence','dark','gloomy']
setting = ['highschool', 'teenager', 'young','office', 'senior', 'old','university','factory','apartment','building','park','car','museum']
gender  = ['man','woman']

# %%
def makeDF(model, word_list):
    g = []
    s = []
    e = []
    j = []
    
    for word in word_list:
        g.append(sklearn.metrics.pairwise.cosine_similarity(model[word].reshape(1,-1), Gender.reshape(1,-1))[0][0])
        s.append(sklearn.metrics.pairwise.cosine_similarity(model[word].reshape(1,-1), Style.reshape(1,-1))[0][0])
        e.append(sklearn.metrics.pairwise.cosine_similarity(model[word].reshape(1,-1), Setting.reshape(1,-1))[0][0])
        j.append(sklearn.metrics.pairwise.cosine_similarity(model[word].reshape(1,-1),Job.reshape(1,-1))[0][0])
    df = pandas.DataFrame({'gender': g, 'setting': e, 'style': s,'job':j}, index = word_list)
    return df

# %%
OCCdf = makeDF(reviewD2V, job) 
Styledf = makeDF(reviewD2V, style)
settingdf = makeDF(reviewD2V, setting)

# %%
vocab = reviewD2V.wv.index2word

# %%
def Coloring(Series):
    x = Series.values
    y = x-x.min()
    z = y/y.max()
    c = list(plt.cm.rainbow(z))
    return c

def PlotDimension(ax,df, dim):
    ax.set_frame_on(False)
    ax.set_title(dim, fontsize = 20)
    colors = Coloring(df[dim])
    for i, word in enumerate(df.index):
        ax.annotate(word, (0, df[dim][i]), color = colors[i], alpha = 0.6, fontsize = 12)
    MaxY = df[dim].max()
    MinY = df[dim].min()
    plt.ylim(MinY,MaxY)
    plt.yticks(())
    plt.xticks(())

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, OCCdf, 'job')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, OCCdf, 'style')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, OCCdf, 'setting')
plt.show()

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, Styledf, 'job')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, Styledf, 'style')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, Styledf, 'setting')
plt.show()

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, settingdf, 'job')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, settingdf, 'style')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, settingdf, 'setting')
plt.show()

# %%
voc = reviewW2V.wv.index2word
voc
# Out:
# ['anime',
#  'story',
#  'characters',
#  'series',
#  'like',
#  'character',
#  'good',
#  'watch',
#  'time',
#  'art',
#  'episode',
#  'episodes',
#  'great',
#  'plot',
#  'way',
#  'music',
#  'love',
#  'animation',
#  'watching',
#  'main',
#  'think',
#  'pretty',
#  'people',
#  'sound',
#  'end',
#  'little',
#  'overall',
#  'movie',
#  'lot',
#  'know',
#  've',
#  'action',
#  'bit',
#  'm',
#  'best',
#  'thing',
#  'better',
#  'things',
#  'scenes',
#  'bad',
#  'seen',
#  'ending',
#  'life',
#  'actually',
#  'interesting',
#  'feel',
#  'makes',
#  'different',
#  'going',
#  'girl',
#  'season',
#  'find',
#  'new',
#  'world',
#  'voice',
#  'manga',
#  'want',
#  'look',
#  'times',
#  'comedy',
#  'watched',
#  'original',
#  'development',
#  'review',
#  'kind',
#  'school',
#  'got',
#  'thought',
#  'probably',
#  'point',
#  'especially',
#  'enjoy',
#  'nice',
#  'fact',
#  'enjoyment',
#  'right',
#  'second',
#  'real',
#  'style',
#  'far',
#  'romance',
#  'found',
#  'girls',
#  'opening',
#  'shows',
#  'long',
#  'enjoyed',
#  'high',
#  'gets',
#  'fan',
#  'definitely',
#  'funny',
#  'unique',
#  'looking',
#  'fun',
#  'amazing',
#  'enjoyable',
#  'short',
#  'liked',
#  'theme',
#  'said',
#  'come',
#  'work',
#  'cast',
#  'nt',
#  'sure',
#  'hard',
#  'reason',
#  'old',
#  'start',
#  'background',
#  'ova',
#  'animes',
#  'felt',
#  'drama',
#  'recommend',
#  'course',
#  'moments',
#  'half',
#  'place',
#  'song',
#  'big',
#  'goes',
#  'quality',
#  'guy',
#  'away',
#  'fight',
#  'worth',
#  'let',
#  'japanese',
#  'sense',
#  'helpful',
#  'mind',
#  'cute',
#  'simply',
#  'comes',
#  'scene',
#  'job',
#  'perfect',
#  'try',
#  'beautiful',
#  'fans',
#  'having',
#  'special',
#  'storyline',
#  'wo',
#  'simple',
#  'completely',
#  'maybe',
#  'use',
#  'understand',
#  'game',
#  'expect',
#  'left',
#  'read',
#  'stories',
#  'mean',
#  'loved',
#  'takes',
#  'given',
#  'trying',
#  'acting',
#  'awesome',
#  'help',
#  'boy',
#  'film',
#  'designs',
#  'favorite',
#  'opinion',
#  'making',
#  'typical',
#  'light',
#  'person',
#  'songs',
#  'beginning',
#  'past',
#  'despite',
#  'op',
#  'instead',
#  'tell',
#  'friends',
#  'soundtrack',
#  'feeling',
#  'truly',
#  'change',
#  'looks',
#  'years',
#  'rest',
#  'later',
#  'day',
#  'parts',
#  'annoying',
#  'based',
#  'able',
#  'human',
#  'note',
#  'personality',
#  'started',
#  'viewer',
#  'death',
#  'true',
#  'boring',
#  'gundam',
#  'certain',
#  'need',
#  'set',
#  'entire',
#  'man',
#  'problem',
#  'fighting',
#  'usually',
#  'drawn',
#  'decent',
#  'important',
#  'cool',
#  'strong',
#  'starts',
#  'somewhat',
#  'getting',
#  'sounds',
#  'fit',
#  'final',
#  'english',
#  'ed',
#  'type',
#  'basically',
#  'arc',
#  'wrong',
#  'themes',
#  'genre',
#  'events',
#  'score',
#  'design',
#  'believe',
#  'average',
#  'dark',
#  'heart',
#  's',
#  'line',
#  'idea',
#  'hate',
#  'yes',
#  'extremely',
#  'gave',
#  'mecha',
#  'eyes',
#  'sort',
#  'humor',
#  'ones',
#  'young',
#  'happen',
#  'attention',
#  'female',
#  'viewers',
#  'called',
#  'relationship',
#  'points',
#  'slow',
#  'effects',
#  'lack',
#  'battle',
#  'version',
#  'happy',
#  'stuff',
#  'excellent',
#  'deep',
#  'dub',
#  'guess',
#  'developed',
#  'perfectly',
#  'voices',
#  'works',
#  'gives',
#  'realistic',
#  'minutes',
#  'seeing',
#  'came',
#  'personalities',
#  'piece',
#  'mood',
#  'play',
#  'happens',
#  'naruto',
#  'friend',
#  'example',
#  'easily',
#  'fairly',
#  'absolutely',
#  'harem',
#  'oh',
#  'laugh',
#  'tv',
#  'hope',
#  'entertaining',
#  'war',
#  'sad',
#  'highly',
#  'artwork',
#  'similar',
#  'male',
#  'etc',
#  'personally',
#  'experience',
#  'case',
#  'easy',
#  'care',
#  'remember',
#  'saw',
#  'heard',
#  'focus',
#  'turn',
#  'depth',
#  'elements',
#  'hell',
#  'fights',
#  'lead',
#  'black',
#  'wanted',
#  'power',
#  'stand',
#  'feels',
#  'certainly',
#  'went',
#  'setting',
#  'major',
#  'face',
#  'hand',
#  'detail',
#  'couple',
#  'normal',
#  'year',
#  'emotions',
#  'played',
#  'small',
#  'matter',
#  'guys',
#  'protagonist',
#  'live',
#  'slice',
#  'level',
#  'huge',
#  'backgrounds',
#  'known',
#  'stop',
#  'random',
#  'emotional',
#  'animated',
#  'actors',
#  'title',
#  'ends',
#  'means',
#  'seriously',
#  'feelings',
#  'aspect',
#  'exactly',
#  'single',
#  'giving',
#  'head',
#  'ecchi',
#  'fast',
#  'problems',
#  'twists',
#  'role',
#  'family',
#  'movies',
#  'particularly',
#  'romantic',
#  'clannad',
#  'order',
#  'lives',
#  'okay',
#  'blood',
#  'wants',
#  'general',
#  'disappointed',
#  'memorable',
#  'finally',
#  'ok',
#  'follow',
#  'happened',
#  'japan',
#  'it&rsquo;s',
#  'fantasy',
#  'screen',
#  'audience',
#  'actual',
#  'terms',
#  'leave',
#  'kinda',
#  'battles',
#  'dramatic',
#  'nature',
#  'star',
#  'epic',
#  'thinking',
#  'detailed',
#  'evil',
#  'totally',
#  'saying',
#  'lots',
#  'add',
#  'looked',
#  'kept',
#  'expected',
#  'unfortunately',
#  'took',
#  'complex',
#  'form',
#  'weird',
#  'moment',
#  'situations',
#  'named',
#  'wonderful',
#  'wish',
#  'ways',
#  'mysterious',
#  'reading',
#  'atmosphere',
#  'group',
#  'told',
#  'days',
#  'close',
#  'complete',
#  'ended',
#  'filler',
#  'decided',
#  'lost',
#  'particular',
#  'changes',
#  'bring',
#  'strange',
#  'compared',
#  'unlike',
#  'shoujo',
#  'coming',
#  'mention',
#  'hilarious',
#  'fantastic',
#  'nicely',
#  'potential',
#  'fits',
#  'shounen',
#  '=',
#  'words',
#  'age',
#  'previous',
#  'supposed',
#  'mystery',
#  'stupid',
#  'fine',
#  'fanservice',
#  'haruhi',
#  'develop',
#  'talking',
#  'aspects',
#  'soon',
#  'super',
#  'space',
#  'plus',
#  'rating',
#  'slightly',
#  'near',
#  'children',
#  'fall',
#  'crazy',
#  'hear',
#  'interest',
#  'tries',
#  'turns',
#  'production',
#  'finished',
#  'number',
#  'written',
#  'quickly',
#  'turned',
#  'reasons',
#  'classic',
#  'supporting',
#  'earth',
#  'visual',
#  'run',
#  'taken',
#  'concept',
#  'details',
#  'middle',
#  'aside',
#  'taking',
#  'obvious',
#  'sister',
#  'generally',
#  'generic',
#  'standard',
#  'god',
#  'situation',
#  'honestly',
#  'pace',
#  'personal',
#  'hair',
#  'future',
#  'interested',
#  'relationships',
#  'introduced',
#  'learn',
#  'questions',
#  'alot',
#  'mentioned',
#  'keeps',
#  'considering',
#  'poor',
#  'shown',
#  'clear',
#  'explain',
#  'sweet',
#  'follows',
#  'usual',
#  'possible',
#  'outstanding',
#  'flaws',
#  'air',
#  'incredibly',
#  'kids',
#  'word',
#  'sex',
#  'magic',
#  'admit',
#  'view',
#  'history',
#  'lines',
#  'notice',
#  'kill',
#  'cry',
#  'large',
#  'writing',
#  'worst',
#  'actions',
#  'chance',
#  'yeah',
#  'reviews',
#  'solid',
#  'hentai',
#  'write',
#  'leaves',
#  'save',
#  'eye',
#  'brings',
#  'changed',
#  'begin',
#  'self',
#  'bleach',
#  'mainly',
#  'present',
#  'talk',
#  'manages',
#  'finish',
#  'masterpiece',
#  'colors',
#  'conclusion',
#  'humans',
#  'geass',
#  'deal',
#  'team',
#  'sequences',
#  'minor',
#  'powerful',
#  'begins',
#  'jokes',
#  'soul',
#  'confusing',
#  'paced',
#  'non',
#  'novel',
#  'terrible',
#  'powers',
#  'sequel',
#  'violence',
#  'worse',
#  'eventually',
#  'kid',
#  'playing',
#  'forward',
#  'pacing',
#  'games',
#  'bored',
#  'older',
#  'fair',
#  'arcs',
#  'popular',
#  'likes',
#  'exciting',
#  'brilliant',
#  'surprised',
#  'plays',
#  'wait',
#  'adventure',
#  'brought',
#  'home',
#  'plenty',
#  'father',
#  'stay',
#  'moving',
#  'city',
#  'filled',
#  'predictable',
#  'nearly',
#  'check',
#  'code',
#  'weak',
#  'service',
#  'tale',
#  'early',
#  'catchy',
#  'involved',
#  'wonder',
#  'cut',
#  'twist',
#  'rock',
#  'angel',
#  'key',
#  'hero',
#  'magical',
#  'likely',
#  'basic',
#  'longer',
#  'emotion',
#  'grow',
#  'added',
#  'purpose',
#  'expecting',
#  'seiyuu',
#  'tone',
#  'explained',
#  'student',
#  'club',
#  'samurai',
#  'needed',
#  'obviously',
#  'premise',
#  'reality',
#  'created',
#  'slowly',
#  'mix',
#  'create',
#  'meaning',
#  'die',
#  'forget',
#  'hit',
#  'appear',
#  'vampire',
#  'dialogue',
#  'ai',
#  'common',
#  'impressive',
#  'honest',
#  'forced',
#  'familiar',
#  'fully',
#  'needs',
#  'doubt',
#  'pure',
#  'brother',
#  'mature',
#  'wanting',
#  'presented',
#  'lucky',
#  'tried',
#  'apart',
#  'ask',
#  'miss',
#  'living',
#  'studio',
#  'biggest',
#  'difficult',
#  'issues',
#  'plain',
#  'roles',
#  'pieces',
#  'night',
#  'd',
#  'clearly',
#  'ago',
#  'horrible',
#  'listen',
#  'straight',
#  'supernatural',
#  'effect',
#  'meets',
#  'evangelion',
#  'robot',
#  'low',
#  'journey',
#  'fitting',
#  'cliche',
#  'fillers',
#  'minute',
#  'odd',
#  'helps',
#  'moe',
#  'realize',
#  'intense',
#  'uses',
#  'list',
#  'cause',
#  'wise',
#  'act',
#  'pick',
#  'fi',
#  'focuses',
#  'impression',
#  'running',
#  'friendship',
#  'bunch',
#  'cg',
#  'sci',
#  'including',
#  'question',
#  'dead',
#  'faces',
#  'leads',
#  'suspense',
#  'women',
#  'giant',
#  'knows',
#  'video',
#  'greatest',
#  'director',
#  'entirely',
#  'mixed',
#  'continue',
#  'spoilers',
#  'shot',
#  'princess',
#  'value',
#  'open',
#  'length',
#  'surprise',
#  'telling',
#  'consider',
#  'modern',
#  'relate',
#  'tend',
#  'adds',
#  'moves',
#  'knew',
#  'book',
#  'silly',
#  '+',
#  'rate',
#  'meant',
#  'visuals',
#  'ridiculous',
#  'touching',
#  'released',
#  'appreciate',
#  'comedic',
#  'child',
#  'following',
#  'earlier',
#  'showing',
#  'constantly',
#  'franchise',
#  'body',
#  'lacking',
#  'horror',
#  'rushed',
#  'suddenly',
#  'tears',
#  'today',
#  'u',
#  'mediocre',
#  'moon',
#  'members',
#  'ability',
#  'happening',
#  'monster',
#  'effort',
#  'rare',
#  'possibly',
#  'progresses',
#  'track',
#  'expectations',
#  'stands',
#  'mother',
#  'match',
#  'sorry',
#  'describe',
#  'deserves',
#  'glad',
#  'content',
#  'na',
#  'woman',
#  'seasons',
#  'surprisingly',
#  'falls',
#  'dull',
#  'managed',
#  'likable',
#  'meet',
#  'appeal',
#  'sadly',
#  'entertainment',
#  'men',
#  'features',
#  'impact',
#  'higurashi',
#  'tracks',
#  'difference',
#  'damn',
#  'appears',
#  'hold',
#  'color',
#  'attempt',
#  'break',
#  'hot',
#  'universe',
#  'shonen',
#  'memories',
#  'boys',
#  'suggest',
#  'addition',
#  'blue',
#  'direction',
#  'sets',
#  'skip',
#  'revolves',
#  'loves',
#  'result',
#  'inside',
#  'metal',
#  'laughing',
#  'gurren',
#  'waste',
#  'touch',
#  'exception',
#  'portrayed',
#  'figure',
#  'suit',
#  'information',
#  'superb',
#  'humour',
#  'thrown',
#  'bright',
#  'bland',
#  'factor',
#  'pop',
#  'shots',
#  'says',
#  'beautifully',
#  'class',
#  'finds',
#  'cat',
#  'greatly',
#  'incredible',
#  'missing',
#  'taste',
#  'spectacular',
#  'majority',
#  'gon',
#  'literally',
#  'heavy',
#  'bgm',
#  'material',
#  'considered',
#  'overly',
#  'younger',
#  'hearted',
#  'repetitive',
#  'otaku',
#  'famous',
#  'worked',
#  'truth',
#  'smooth',
#  'x',
#  'hooked',
#  'creators',
#  'appropriate',
#  'ideas',
#  '2nd',
#  'ass',
#  'favourite',
#  'teacher',
#  'room',
#  'deeper',
#  'society',
#  'sit',
#  'bebop',
#  'crap',
#  'imagine',
#  'gore',
#  'gone',
#  'confused',
#  'focused',
#  'dream',
#  'names',
#  'choice',
#  'military',
#  'disappointing',
#  'hardly',
#  'don&rsquo;t',
#  'childhood',
#  'remains',
#  'tells',
#  'outside',
#  'references',
#  'compare',
#  'comic',
#  'beat',
#  'impressed',
#  'plots',
#  'barely',
#  'force',
#  'lagann',
#  'episodic',
#  'monsters',
#  'train',
#  'suppose',
#  'variety',
#  'fluid',
#  'caught',
#  'darker',
#  'message',
#  'revealed',
#  'adaptation',
#  'wondering',
#  'money',
#  'ultimately',
#  'sakura',
#  'master',
#  'budget',
#  'draw',
#  'picture',
#  'sword',
#  'thoughts',
#  'designed',
#  'robots',
#  'stick',
#  'executed',
#  'notch',
#  'killed',
#  'fresh',
#  'natural',
#  'normally',
#  'endings',
#  'town',
#  'appearance',
#  'dvd',
#  'win',
#  'introduction',
#  'innocent',
#  'leaving',
#  'individual',
#  'flat',
#  'hated',
#  'approach',
#  'total',
#  'starting',
#  'free',
#  'miyazaki',
#  'manner',
#  'seed',
#  'refreshing',
#  'thanks',
#  'element',
#  'demon',
#  'seemingly',
#  'drawing',
#  'helped',
#  'macross',
#  'till',
#  'ordinary',
#  'conflict',
#  'recommended',
#  'ni',
#  'awkward',
#  'rarely',
#  'lelouch',
#  'complain',
#  'fate',
#  'believable',
#  'writers',
#  'alright',
#  'issue',
#  'tokyo',
#  'share',
#  'pay',
#  'makoto',
#  'students',
#  'protagonists',
#  'driven',
#  'ghost',
#  'noticed',
#  'scenery',
#  'decide',
#  'secret',
#  'villains',
#  'creepy',
#  'killing',
#  'quick',
#  'lame',
#  'titles',
#  'subtle',
#  ...]

# %%
def adprob(ad, model):
    sen_scores = model.score(ad, len(ad))
    ad_score = sen_scores.mean()
    return ad_score

# %%
W2Vmodel = gensim.models.Word2Vec(review_df['normalized_words'], min_count=0, size=100, hs=1, negative=0) 
review_df['likelihood'] = review_df['normalized_sents'].apply(lambda x: adprob(x, W2Vmodel))
#help(word_vectors)

# %%
for ad in review_df.sort_values(by = 'likelihood', ascending = False)['review'][-5:]:
    print (ad + '\n\n')
# Out:
# NOTE: This review is intended to cover Gantz in its entirety.Gantz is about as close as you�ll ever get to a love it or hate it anime. It�s littered with so much gore, profanity, nudity, and sex that it�ll either immediately turn you off or immediately glue your eyes to the screen. Being a person from the latter group I have to say I absolutely loved Gantz right from the start. Well, okay, not exactly right from the start. Gantz starts out in the life of Kei Kurono, an angst ridden teenager who has nothing better to do but think negatively to himself and get                  boners in class. He�s always worrying about something, and doesn�t care about anyone else except for himself. To put it simply, he�s like an emo kid on acid. He complains about everything, but mostly dwells on the fact that he�s never gotten laid. Hmm�wonder why. Ten minutes of listening to this punk whine and cry while so eloquently squeezing in the occasional F-word and I dare anyone to not want to turn this anime off and forget all about it. Thankfully things pick up from there, albeit with all the whining and crying still intact.After we get acquainted with our main protagonist we get to meet Katou. Katou is an old time friend of Kei�s who used to look up to him. You see, before Kei was a whinny little punk he was actually a really cool and adventurous kid. Lack of character development doesn�t exactly show why Kei went from hero to zero, but Katou tries to emulate the Kei he once knew throughout the series, starting with attempting to save a homeless guy who fell on the subway tracks, with the help of Kei of course. Here is where the feces (and blood, guts, and various other nasty things) really hits the fan. Kei and Katou successfully aid the drunk homeless guy to safety, but soon realize that a subway is coming their way. Their plan of avoiding it? Run up the tracks passed where the subway should stop. Bad plan? You bet. I don�t know about you, but I�d much rather try my luck at climbing back onto the platform rather than outrunning a damn subway train. But that�s just me. It turns out that Subway isn�t going to stop at the station after all, and both Kei and Katou are royally screwed. They get hit, and heads go flying.Welcome to the true start of Gantz. Here is where things go beyond the boundaries of typical anime. Here is where things get fun. Kei and Katou wake up in this room with a number of random people who all seem to have died. They can�t leave the room, and trying to make sense out of it all is only a waste of time. Introduced into the story next is who I like to call the third wheel. Her name is also Kei, but like everyone else in the series I�ll just call her Kishimoto. Kishimoto serves little to no purpose other than for Kei to obsess and angst over, and as fan service, but with her flakey and often times clueless personality I don�t think she�s doing anyone a service. Luckily Gantz isn�t about character depth; it�s all about violence, nudity, and all that juicy stuff. That�s where the true main character of the anime comes in: Gantz. Gantz is probably one of the coolest anime characters to come around in years, and he doesn�t even have to say a word. He�s psychotic, yet fully in control. He�s evil, yet lovable. He�s the gears in the machine.Gantz is a game of survival that you can�t help but love. Everyone in the room is soon transported to an area of town and can�t leave until they have eliminated the targets selected by Gantz. These targets are as wacky as they are terrifying, and while many of them look harmless or relatively easy to dispatch of that is rarely the case. Part of the excitement of watching Gantz comes from not knowing what everyone will have to go up against next. It�s also worth mentioning that this isn�t your typical �bad guy of the week� series. Each time our reluctant cast is forced into battle it usually lasts for a lot more than just a single episode. This is good, because Gantz is one anime that will probably  ...
#
#
# Silent Mobius is a mish-mash of a lot of different things. It has magic, cyborgs, aliens, hackers, and that�s just when you scratch the surface. Usually when an anime tries to mix this many things together the result is pretty poor, but in the case of Silent Mobius it�s a complete success. One of the first things I noticed when watching Silent Mobius was how familiar it all felt. You have your �science project gone wrong� doomsday scenario followed by what can only be described as hell on Earth, and then we pan out to about 30 years later where a special organization (the AMP)                  exists to battle the threat and protect what�s left of the world around them. For some reason I felt like I�ve been here before. The second thing I noticed about the show? How badly some of the names translated into English. Katsumi Liqueur; Yuki Saiko; Lebia Maverick. The nice girl of the anime ironically has a last name that says otherwise, and the computer whiz of the show has a name that resembles a certain part of the female anatomy that male readers under the age of thirteen probably shouldn�t know about. It�s times like this when I can understand why some studios change the names of characters in the dubbing process. Speaking of dubbing, Silent Mobius has one of the worst dubs I�ve heard in a while. Some of the characters are alright (not great, but alright) such as Kiddy and Katsumi, but other characters are so painful to listen to that it almost temps me to drop my final score of this anime down a few notches. The one voice actor who got on my nerves the most was Barry W. Levy who provided the voice for Robert (Roy) DeVice. I don�t know who his voice coach was, but he had this horrible habit of putting a period after every word he said (so.he.talked.like.this.), which got annoying quick. And don�t even get me started on his weak display of emotions. Every time there was an emotional scene with Roy (especially a crying scene) I wanted to close my eyes and pretend it wasn�t happening. How this guy gets to play alongside Matthew Perry in an upcoming movie is beyond me, but since Silent Mobius came out nearly ten years ago I�ll give him the benefit of the doubt. If all you have to do to escape Barry Levy�s voice (although granted he�s not the only crappy voice actor here, just my pick for bad tomato) is put up with reading subtitles I�d say it�s well worth it. Japanese audio is the way to go with this series, trust me.One thing I found rather interesting was how the setting of the series was like a character all on it�s own. It�s very distinct and memorable. It�s almost like a futuristic post-apocalyptic version of Gotham, where governments have pretty much turned their heads away from the state of the city and have essentially helped in making it the mess that it is. Also much like Gotham the city has two sides to itself. It has its rather nice residential areas where people of higher class can live respectably, and then it has the broke down and poor parts where nobody (especially cops and AMP members) should ever go. One of the early episodes had our heroine-in-training Katsumi Liqueur and her soon to be boyfriend and fellow police officer Roy get trapped in the worst part of town after their vehicle crashes (with the help of a little sabotage, of course), and they had to make their way around without drawing attention to themselves, which meant they needed to change into something a little less �cop-like�. This is probably the first episode that really pulled me in because it gave so much life to the city depicted in the series. Later episodes further expand upon this, but they don�t forget about the cast members either. Each of the characters of Silent Mobius have at least one episode almost entirely devoted to them, which is always a welcomed aspect when in need of a little character development. When the series first started it felt a lot like my first day of school. I didn�t know any of the characters, and certainly wasn�t a ...
#
#
# Blue Gender: The Warrior is a retelling of the Blue Gender series with a few minor (and some major) adjustments. If you�re not willing or unable to sit through the entire 26 episodes of Blue Gender but still want to see what it�s all about then this movie would probably be the way to go, but that does come at a price. The Warrior is what you get when you try to cram a 26 episode series into a hour and a half long movie. A rushed piece of mediocrity that doesn�t leave much room for anything other than quick deaths and awkwardly paced character                  development. While it more or less maintains the plot elements featured in the series, it all but misses some of the strongest moments that redeemed the series during some of its darker hours. Not only are a lot of characters killed off way too quickly, but some of them aren�t even introduced. Also, I found it rather insulting that The Warrior used a lot of the scenes from the series out of their original context. For some reason they must have felt it was okay to show the series' final battle in the movie as being nothing but a random fight, and then one of the minor battles from the series turns out to be the movies climax. This irked me for some reason, and I can�t help but be reminded of that really bad Shenmue machinima that came with Shenmue 2. Don�t ask me why. I just felt the same level quality in The Warrior as I recall feeling when I first watched that horrible Shenmue �movie.� Anyways, The Warrior isn�t all bad. Some scenes that were thrown in were actually quite interesting, such as the brawl between Marlene and Yuji. Also that when Yuji wakes up after 22 years of sleep his hair is actually long and has to be cut. Good job there. But so many other things are missing that it�s hard to fully appreciate the story for what it�s worth. The character development and ultimate destiny between Yuji and Marlene generally stay the same, but because this movie sums everything up in just a little over a hour and a half it feels very weak and synthetic. To make matters worse, a lot of the most necessary plot arcs are nowhere to be seen in the movie. The introduction of the Sleeper Brigade and their eventual fall from grace, and the scientist who decides to take over Second Earth by overthrowing its government are two of the most important plot devices that never come into play in The Warrior. Simply put, The Warrior doesn�t feel as alive as its series counterpart does. It just doesn�t do a very good job at summing up the entire series (if that was even what it was trying to do, as it�s hard to tell with all of the reused animation from the series), and quite frankly if you watched this after watching the series (like me) you would probably be pretty turned off (like me). It�s not entirely bad on its own, but fails at being anything more than just average. A few things are improved here and there, but not nearly enough for me to suggest you watch this instead or before the series. If you�re a die hard Blue Gender fan then I guess you can appreciate this more, but if you�ve never touched the series before then I�d recommend you just stick to the episodes and stay away from this flick.My Score: 6.5Version Watched: English Dub
#
#
# Ah, post apocalyptic animes are so much fun. I love how they always manage to over-dramatize the end of the world, a story arc that you would think has enough drama on its own. Sarcasm aside, Blue Gender is a surprisingly deep sci-fi drama with a lot going for it. Before I get started on the actual review though, let me just point out that the content rating on this anime seems to always be wrong wherever I go, including on the box set. I bought the collectors box set at Best Buy and after checking the back for the content rating I see that                  it has it listed as �TV-PG.� TV-PG?! They must be nuts! Blue Gender has more people getting killed in single scenes than most of the goriest animes even have. Not just soldiers, but women and children as well. I don�t know, but I wouldn�t want little Timmy or Susie watching this in place of Pokemon expecting to be whisked away to some dreamy sci-fi fantasy world. No, Blue Gender is serious business, and certainly not TV-PG. Other sources have it listed as PG-13, but I can�t see how that�s right either. Besides the gore there is quite a bit of nudity, sex, and various other adult situations that I don�t think would make its way into any PG-13 movie I�ve ever seen. There are even a few scenes with orgies in them (yes, orgies). Hell, even the ED has full nudity in it. I�m calling this one �R� and I�m sticking to it, feel free to give it your own rating though if you feel mine is too drastic. Blue Gender starts out simple enough. The Earth has been overrun by creatures known simply as Blue, and the remaining human race is struggling to take their planet back from them. For the first couple of episodes it�s the atmosphere and how the characters interact within it that really makes the show stand out. Everything feels as dead as it looks, and the characters all have this very emotionless way of going about themselves that is actually quite frightening. The main heroine (Marlene) especially. She�s this tough ass soldier chick who doesn�t care about anything except for the mission. She doesn�t care if her comrades die, and civilians are nothing but obstacles to her. In a way she�s more machine than she is human, mentally programmed to carry out her duties and nothing more. Yuji is one of the few cast members in the entire series that shows emotions and personality outside of the soldier, but it pretty much falls to deaf ears for more than half the series. Since I enjoy making comparisons, I�d consider it safe to say that fans of films like Aliens and The Thing would enjoy Blue Gender quite a bit. While none of those movies were post apocalyptic in any way, they both have a very similar feel to Blue Gender. A very dry, dead, scary and rather depressing feel, and where characters are very two dimensional only due to the fact that they don�t know how to act otherwise, constantly in fear or ready for combat. This is the world of Blue Gender in a nutshell.Like I said earlier, Blue Gender is a pretty depressing anime. It doesn�t pull any punches, and doesn�t leave too many characters alive for very long. But besides that, it�s also rather sad to see mankind forced into outer space to live in some space station they call �Second Earth� all because of some giant bug infestation. I find it pretty far fetched that mankind, as stubborn as it is, didn�t just nuke the hell out of Earth before letting the Blue take it over and multiply even more in a sort of �if we can�t have it then nobody can� type of deal. Or at least dropped a few tactical strikes on the locations with the most Blue and then sent in an assault team to take out the rest. But, what do I know? It�s not like I�ve ever been in a post apocalyptic reality before. Without nitpicking too much though I will compliment the series on its cultural diversity. Besides Yuji and a few others, the characters all seem to range in nationality. This is a problem I always had with most post apocalyptic stories regardless of it being an anime or s ...
#
#
# Gundam X got a bad reputation due to the bad timing where it was aired along with Shin Seiki Evangelion which got a big hits and Gundam X was somehow forgotten. But, personally I think the anime is quite good and has some uniqueness that makes me can't forget it... and V Gundam anime was even worse.          Helpful

# %%
adprob([["lovely", "boy"]], W2Vmodel)
# Out:
# -19.101505

# %%
adprob([["lovely", "girl"]], W2Vmodel)
# Out:
# -13.613995

# %%
from gensim.models import FastText
model_ted = FastText(review_df_h['normalized_words'], size=100, window=5, min_count=5, workers=4,sg=1)

# %%
review_df.groupby(["workName",'peopleFoundUseful','overallRating'])[['likelihood']].mean().sort_values('likelihood', ascending = False)[700:750
                                                                                                                                       ]
# Out:
#                                                                                     likelihood
# workName                                           peopleFoundUseful overallRating
# Shakugan_no_Shana                                  7                 9              -34.889816
# Kareshi_Kanojo_no_Jijou                            47                8              -34.925137
# Code_Geass__Hangyaku_no_Lelouch                    7                 7              -34.928329
# Kaze_no_Stigma                                     14                8              -34.930141
# Rizelmine                                          32                6              -34.965286
# Kiniro_no_Corda__Primo_Passo_-_Hitonatsu_no_Encore 34                9              -34.990150
# Bishoujo_Senshi_Sailor_Moon                        17                10             -35.017872
# Himesama_Goyoujin                                  8                 5              -35.018826
# Time_Bokan                                         12                7              -35.020397
# Code_Geass__Hangyaku_no_Lelouch                    1                 9              -35.064583
# Cardcaptor_Sakura                                  28                7              -35.068069
# Elfen_Lied                                         47                2              -35.086819
# Suzumiya_Haruhi_no_Yuuutsu                         1                 9              -35.096127
# Shakugan_no_Shana                                  13                9              -35.106911
# Koukyoushihen_Eureka_Seven                         10                10             -35.111795
# Maburaho                                           54                9              -35.111935
# Konjiki_no_Gash_Bell__Mecha_Vulkan_no_Raishuu      20                10             -35.123138
# Genshiken                                          11                8              -35.123989
# Inukami                                            86                6              -35.126244
# Princess_Princess                                  5                 6              -35.129192
# True_Tears                                         23                2              -35.129574
# Suzumiya_Haruhi_no_Yuuutsu                         3                 10             -35.151115
# Jyu_Oh_Sei                                         7                 10             -35.158318
# ef__A_Tale_of_Memories                             4                 10             -35.193363
# Higurashi_no_Naku_Koro_ni                          9                 9              -35.214607
# Asgaldh__The_Distortion_Testament                  81                4              -35.221607
# One_Piece                                          18                10             -35.223274
# Kodomo_no_Omocha_TV                                95                10             -35.227798
# Death_Note                                         120               9              -35.232830
# Tokyo_Majin_Gakuen_Kenpucho__Tou                   58                9              -35.235863
# Super_GALS_Kotobuki_Ran                            10                9              -35.248932
# Toki_wo_Kakeru_Shoujo                              2                 9              -35.257334
# Death_Note                                         137               3              -35.260605
# Code_Geass__Hangyaku_no_Lelouch                    3                 9              -35.288465
# Death_Note                                         18                8              -35.289871
# Mahou_Shoujo_Lyrical_Nanoha_StrikerS               33                8              -35.323837
# Gokudou-kun_Manyuuki                               25                10             -35.334061
# Death_Note                                         190               10             -35.355274
# DearS                                              11                6              -35.356579
# Ring_ni_Kakero_1                                   10                10             -35.360435
# Stranger__Mukou_Hadan                              2                 9              -35.365765
# Nishi_no_Yoki_Majo__Astraea_Testament              13                10             -35.366360
# Rizelmine                                          28                6              -35.369690
# Tokyo_Mew_Mew                                      25                8              -35.384346
# Seraphim_Call                                      27                4              -35.390675
# Black_Blood_Brothers                               70                9              -35.431232
# Claymore                                           1                 10             -35.433701
# RG_Veda                                            16                3              -35.436058
# Yakitate_Japan                                     59                9              -35.442547
# Hajime_no_Ippo                                     827               10             -35.477367

# %%
review_df.groupby(["overallRating",'characterRating','soundRating'])[['likelihood']].mean().sort_values('likelihood', ascending = False)
# Out:
#                                            likelihood
# overallRating characterRating soundRating
# 5             8               6            -16.275427
# 1             1               3            -23.069838
# 4             1               6            -24.837862
# 10            8               6            -25.531723
# 9             0               9            -25.857782
# ...                                               ...
# 5             3               2           -123.865608
# 7             4               7           -128.704071
# 5             3               3           -132.407089
# 1             1               4           -134.786083
# 4             10              8           -155.807220
#
# [421 rows x 1 columns]

# %%
review_df.groupby("author")[['likelihood']].mean().sort_values('likelihood', ascending = False)
# Out:
#                   likelihood
# author
# F0RR              -10.036272
# HugGaara          -13.768100
# kaoru88           -15.424953
# BadLuckTuck       -16.552422
# Lirima            -17.220730
# ...                      ...
# SunoharaMaster90 -150.204891
# death_oni666     -152.560974
# 7Th              -152.817764
# schizophrenic    -160.820648
# ChronoBallX      -184.932159
#
# [1947 rows x 1 columns]

# %%
model_ted.wv.most_similar('robot')
# Out:
# [('robot\\', 0.9498561024665833),
#  ('robots', 0.8868048191070557),
#  ('robo', 0.8821775913238525),
#  ('robotnik', 0.8719408512115479),
#  ('robotic', 0.8576734066009521),
#  ('robotics', 0.8554517030715942),
#  ('robotech', 0.8072638511657715),
#  ('giant', 0.7923586368560791),
#  ('rob', 0.7885173559188843),
#  ('mech', 0.7530350685119629)]

# %%
si = word_vectors.wv.most_similar("anime")
si
# Out:
# [('manga', 0.8306878209114075),
#  ('live-action', 0.7139478921890259),
#  ('ova', 0.6849613189697266),
#  ('animated', 0.6658540964126587),
#  ('spin-off', 0.6460409164428711),
#  ('cartoon', 0.6258808374404907),
#  ('adaption', 0.6165875196456909),
#  ('comic', 0.6111397743225098),
#  ('animation', 0.6100625991821289),
#  ('sci-fi', 0.6085641384124756)]

# %%
import copy

def calc_syn0norm(model):
    return (model.wv.syn0 / np.sqrt((model.wv.syn0 ** 2).sum(-1))[..., np.newaxis]).astype(np.float32)

def smart_procrustes_align_gensim(base_embed, other_embed, words=None):
    base_embed = copy.copy(base_embed)
    other_embed = copy.copy(other_embed)
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed, words=words)


    base_vecs = calc_syn0norm(in_base_embed)
    other_vecs = calc_syn0norm(in_other_embed)

    
    m = other_vecs.T.dot(base_vecs) 

    u, _, v = np.linalg.svd(m)
    # another matrix operation
    ortho = u.dot(v) 
    # Replace original array with modified one
    # i.e. multiplying the embedding matrix (syn0norm)by "ortho"
    other_embed.wv.syn0norm = other_embed.wv.syn0 = (calc_syn0norm(other_embed)).dot(ortho)
    return other_embed

def intersection_align_gensim(m1,m2, words=None):
    # Get the vocab for each model
    vocab_m1 = set(m1.wv.vocab.keys())
    vocab_m2 = set(m2.wv.vocab.keys())

    # Find the common vocabulary
    common_vocab = vocab_m1&vocab_m2
    if words: common_vocab&=set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1-common_vocab and not vocab_m2-common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.wv.vocab[w].count + m2.wv.vocab[w].count,reverse=True)

    # Then for each model...
    for m in [m1,m2]:
        # Replace old syn0norm array with new one (with common vocab)
        indices = [m.wv.vocab[w].index for w in common_vocab]
        old_arr = calc_syn0norm(m)
        new_arr = np.array([old_arr[index] for index in indices])
        m.wv.syn0norm = m.wv.syn0 = new_arr

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        m.index2word = common_vocab
        old_vocab = m.wv.vocab
        new_vocab = {}
        for new_index,word in enumerate(common_vocab):
            old_vocab_obj=old_vocab[word]
            new_vocab[word] = gensim.models.word2vec.Vocab(index=new_index, count=old_vocab_obj.count)
        m.wv.vocab = new_vocab

    return (m1,m2)

# %%
review_df['postTime2'] = review_df['postTime'].str.split('-').str.get(0)
review_df['postTime2']
review_df
# Out:
#           id workId reviewId                                  workName  \
# 0       8121      1        1                              Cowboy_Bebop
# 1      63480    856        9                             Utawarerumono
# 2       8452    263       10                            Hajime_no_Ippo
# 3      66544    129       11                      Gensoumaden_Saiyuuki
# 4      55936    210       12                                   Ranma_½
# ...      ...    ...      ...                                       ...
# 14995  30576    121    31205                       Fullmetal_Alchemist
# 14996  49847   1689    31206                     Byousoku_5_Centimeter
# 14997  33545   2167    31209                                   Clannad
# 14998  54369   8525    31214                  Kami_nomi_zo_Shiru_Sekai
# 14999  87316   1259    31216  Saint_Seiya__Tenkai-hen_Josou_-_Overture
#
#                   postTime episodesSeen         author peopleFoundUseful  \
# 0      2006-11-07 18:34:00           26          Xinil               162
# 1      2006-11-08 00:24:00           26        Crystal               218
# 2      2006-11-08 14:39:00           76          Xinil               827
# 3      2006-11-09 05:22:00           50         Chelle                69
# 4      2006-11-09 16:48:00          161  running_lemon                40
# ...                    ...          ...            ...               ...
# 14995  2010-10-08 12:59:00           51          otyme                 2
# 14996  2010-10-08 13:25:00            3  kirathesavior                 1
# 14997  2010-10-08 16:11:00           23         xm0123                 6
# 14998  2010-10-08 20:28:00            1      Sugarsync                 6
# 14999  2010-10-09 00:18:00            1         rahvii                10
#
#       overallRating storyRating animationRating soundRating characterRating  \
# 0                10           8              10          10              10
# 1                 8           8               7           7               9
# 2                10          10               9           9              10
# 3                 9           8               6           7              10
# 4                 7           6               8           8               8
# ...             ...         ...             ...         ...             ...
# 14995            10           9               8           7              10
# 14996             8           8               9           9               8
# 14997            10           9               9          10              10
# 14998             9           9               8           9               8
# 14999             6           6               6           4               7
#
#       enjoymentRating                                             review  \
# 0                  10  Cowboy Bebop is an episodic series. By episodi...
# 1                   8  Utawarerumono manages to be one of those harem...
# 2                  10  First, let me say that I\\'m not a fan of boxi...
# 3                   9  Saiyuki is one of those animes that just grabs...
# 4                   7  A comedy/romance based on the manga by Rumiko ...
# ...               ...                                                ...
# 14995               9  Story:The story is about Edward Elric (I found...
# 14996              10  this movie was really heart warming. the chara...
# 14997              10  Clannad was originally a visual novel for the ...
# 14998               9  *this is the detail from the review i wrote in...
# 14999               7  First half of the movie is extremely boring. T...
#
#       postTime2                                    tokenized_sents  \
# 0          2006  [[Cowboy, Bebop, is, an, episodic, series], [B...
# 1          2006  [[Utawarerumono, manages, to, be, one, of, tho...
# 2          2006  [[First, let, me, say, that, I\\'m, not, a, fa...
# 3          2006  [[Saiyuki, is, one, of, those, animes, that, j...
# 4          2006  [[A, comedy, romance, based, on, the, manga, b...
# ...         ...                                                ...
# 14995      2010  [[Story], [The, story, is, about, Edward, Elri...
# 14996      2010  [[this, movie, was, really, heart, warming], [...
# 14997      2010  [[Clannad, was, originally, a, visual, novel, ...
# 14998      2010  [[this, is, the, detail, from, the, review, i,...
# 14999      2010  [[First, half, of, the, movie, is, extremely, ...
#
#                                         normalized_sents
# 0      [[cowboy, bebop, episodic, series], [episodic,...
# 1      [[utawarerumono, manages, harem, animes, possi...
# 2      [[let, i\\'m, fan, boxing], [fact, pretty, hat...
# 3      [[saiyuki, animes, grabs, episode, wo, let, ep...
# 4      [[comedy, romance, based, manga, rumiko, takah...
# ...                                                  ...
# 14995  [[story], [story, edward, elric, found, eduard...
# 14996  [[movie, heart, warming], [characters, unique,...
# 14997  [[clannad, originally, visual, novel, pc], [ky...
# 14998  [[detail, review, wrote, manga*tamiki, wakiki,...
# 14999  [[half, movie, extremely, boring], [story, tim...
#
# [15000 rows x 18 columns]

# %%
def compareModels(df, category, text_column_name='normalized_sents', sort = True, embeddings_raw={}):
    """If you are using time as your category sorting is important"""
    if len(embeddings_raw) == 0:
        embeddings_raw = rawModels(df, category, text_column_name, sort)
    cats = sorted(set(df[category]))
    #These are much quicker
    embeddings_aligned = {}
    for catOuter in cats:
        embeddings_aligned[catOuter] = [embeddings_raw[catOuter]]
        for catInner in cats:
            embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_raw[catInner]))
    return embeddings_raw, embeddings_aligned

# %%
def rawModels(df, category, text_column_name='normalized_sents', sort = True):
    embeddings_raw = {}
    cats = sorted(set(df[category]))
    for cat in cats:
        #This can take a while
        print("Embedding {}".format(cat), end = '\r')
        subsetDF = df[df[category] == cat]
        print(subsetDF)
        #You might want to change the W2V parameters
        embeddings_raw[cat] = gensim.models.word2vec.Word2Vec(subsetDF[text_column_name].sum())
    return embeddings_raw

# %%
rawEmbeddings, comparedEmbeddings = compareModels(review_df, 'postTime2')
#rawModels(review_df,'postTime2')
# Out:
#         id workId reviewId                           workName  \
# 0     8121      1        1                       Cowboy_Bebop
# 1    63480    856        9                      Utawarerumono
# 2     8452    263       10                     Hajime_no_Ippo
# 3    66544    129       11               Gensoumaden_Saiyuuki
# 4    55936    210       12                            Ranma_½
# 5    22039    486       13  Kino_no_Tabi__The_Beautiful_World
# 6    68626    145       14            Kareshi_Kanojo_no_Jijou
# 7    18797    136       15                    Hunter_x_Hunter
# 8    43899    268       16                         Golden_Boy
# 9    18796    136       17                    Hunter_x_Hunter
# 10  101808    751       18                  Bomberman_Jetters
# 11   44952     24       19                      School_Rumble
# 12   62242    226       20                         Elfen_Lied
# 13  104779   1214       21           Binbou_Shimai_Monogatari
# 14   45780     28       22                     Yakitate_Japan
# 15   80158    167       23                  Scrapped_Princess
# 16   56061    534       25                            Slayers
# 17   83291    101       26                                Air
# 18   88044    104       27                    Ayashi_no_Ceres
# 19   45804     28       29                     Yakitate_Japan
# 20  116762    133       30                        Green_Green
# 21   85364    485       31                   Damekko_Doubutsu
# 22   31564    235       32                    Detective_Conan
# 23   32101   1453       33                      Maison_Ikkoku
# 24   60372   1293       34                     Urusei_Yatsura
# 25  111694   1198       35                          Tsuyokiss
# 26   16932    205       36                   Samurai_Champloo
# 27   56081    407       37                    Tantei_Gakuen_Q
# 28  119177    881       38                    Green_Green_OVA
# 29   84336    565       39                           Steamboy
# 30   27052    853       40             Ouran_Koukou_Host_Club
# 31   37003    135       41                       Hikaru_no_Go
# 32   68974    857       44                           Air_Gear
# 33   79832     68       47                          Black_Cat
#
#                postTime episodesSeen            author peopleFoundUseful  \
# 0   2006-11-07 18:34:00           26             Xinil               162
# 1   2006-11-08 00:24:00           26           Crystal               218
# 2   2006-11-08 14:39:00           76             Xinil               827
# 3   2006-11-09 05:22:00           50            Chelle                69
# 4   2006-11-09 16:48:00          161     running_lemon                40
# 5   2006-11-10 06:43:00           13            Chelle               104
# 6   2006-11-10 20:03:00           26           Crystal               247
# 7   2006-11-12 07:41:00           62          Braveone                30
# 8   2006-11-12 09:37:00            6          Braveone                32
# 9   2006-11-13 14:53:00           62        AngelIvory                34
# 10  2006-11-13 15:44:00           52        AngelIvory                11
# 11  2006-11-13 17:17:00           26        AngelIvory               273
# 12  2006-11-14 13:36:00           13        Ubermensch               739
# 13  2006-11-15 14:28:00           10           martino                49
# 14  2006-11-15 15:53:00           69        AngelIvory                49
# 15  2006-11-18 11:55:00           24         DarkLaila                59
# 16  2006-11-18 16:06:00           26     running_lemon                27
# 17  2006-11-24 06:48:00           13              June                22
# 18  2006-11-24 06:52:00           24              June                10
# 19  2006-11-24 06:59:00           69              June                 2
# 20  2006-11-24 09:45:00           12           martino               150
# 21  2006-11-24 10:53:00           26        AngelIvory                14
# 22  2006-11-25 19:42:00               MeitanteiShakura               354
# 23  2006-11-26 12:58:00           96  MeitanteiShakura                48
# 24  2006-11-26 13:59:00          195  MeitanteiShakura               121
# 25  2006-12-12 14:27:00           12           martino                58
# 26  2006-12-16 01:07:00           26               Jin               194
# 27  2006-12-20 19:24:00           45           Crystal                40
# 28  2006-12-24 06:47:00            1           martino                33
# 29  2006-12-24 09:46:00            1             Xinil                49
# 30  2006-12-24 09:54:00           26             Xinil               174
# 31  2006-12-24 13:30:00           75            Hiromi                48
# 32  2006-12-28 16:56:00           25             VyseN                17
# 33  2006-12-31 23:27:00           23             Ceray               177
#
#    overallRating storyRating animationRating soundRating characterRating  \
# 0             10           8              10          10              10
# 1              8           8               7           7               9
# 2             10          10               9           9              10
# 3              9           8               6           7              10
# 4              7           6               8           8               8
# 5              9           9               9           8               9
# 6              8           8               6           7               9
# 7             10          10               8           9              10
# 8             10          10               9           7              10
# 9             10          10               8           8              10
# 10             9           9               9           7               7
# 11            10           8              10          10              10
# 12            10          10               8          10               9
# 13             8           7               7           9               9
# 14             9           9               7           9              10
# 15             9           9               8           8               9
# 16             7           8               7           7               6
# 17             5           3               9           7               8
# 18             6           7               4           8               7
# 19             7           7               6           7               7
# 20             8           6               8           9               8
# 21             7           7               8           6               8
# 22             9           9               9           8               8
# 23             8           9               7           7               9
# 24             9           9               6           8               8
# 25             8           7               8           8               8
# 26             9           8               9          10               9
# 27             7           8               6           7               6
# 28             5           4               6           6               5
# 29             8           9               8           8               8
# 30             8           8               9           8              10
# 31             8           9               8           8               7
# 32             8           8               9           7               6
# 33             9           7              10           9               9
#
#    enjoymentRating                                             review  \
# 0               10  Cowboy Bebop is an episodic series. By episodi...
# 1                8  Utawarerumono manages to be one of those harem...
# 2               10  First, let me say that I\\'m not a fan of boxi...
# 3                9  Saiyuki is one of those animes that just grabs...
# 4                7  A comedy/romance based on the manga by Rumiko ...
# 5                9  What do you say about an anime that is just ab...
# 6                8  Kare Kano was a romance anime that could have ...
# 7               10  Overall:  My very best anime and i haven't act...
# 8               10  Overall:Honestly I really don't care about oth...
# 9               10  Hunters… What do you think about when you hear...
# 10               9  Bomberman, if you liked the game then you will...
# 11              10  Hate watching those anime that drag on for too...
# 12              10  Elfen Lied is something else. Just watching th...
# 13               8  ===Animation===Toei did a pretty good job with...
# 14               9  Love bread?  Ever wondered how they make it?  ...
# 15              10  Scrapped Princess is a quite interesting genre...
# 16               7  Slayers is a comedy/adventure/fantasy anime di...
# 17               3  If you'd like to see my full review than leave...
# 18               7  If you'd like to see my full review then leave...
# 19               4  If you'd like to see my full review then leave...
# 20               8  ===Animation===Quite nice and steady animation...
# 21               7  As the name suggests this anime is about a loa...
# 22              10  It's funny.  I'm not the type of person that w...
# 23               8  I find it a bit disheartening that most fans p...
# 24               9  Back in my \"Maison Ikkoku\" review, I mention...
# 25               9  ===Foreword===In this review I might be quite ...
# 26              10  Samurai Champloo is the latest work from Write...
# 27               7  Tantei Gakuen Q is pretty much just another de...
# 28               2  ===Animation===Looking back at the original Gr...
# 29               8  First, let me say that I wasn't expecting much...
# 30               9  Looking for a show to laugh your ass off? Look...
# 31               8  An anime about a grade school boy playing a bo...
# 32               8  I first found Air Gear when I was looking for ...
# 33               9  Gah~ Ceray's Review Time (procrastination in d...
#
#    postTime2                                    tokenized_sents  \
# 0       2006  [[Cowboy, Bebop, is, an, episodic, series], [B...
# 1       2006  [[Utawarerumono, manages, to, be, one, of, tho...
# 2       2006  [[First, let, me, say, that, I\\'m, not, a, fa...
# 3       2006  [[Saiyuki, is, one, of, those, animes, that, j...
# 4       2006  [[A, comedy, romance, based, on, the, manga, b...
# 5       2006  [[What, do, you, say, about, an, anime, that, ...
# 6       2006  [[Kare, Kano, was, a, romance, anime, that, co...
# 7       2006  [[Overall, My, very, best, anime], [and, i, ha...
# 8       2006  [[Overall, Honestly, I, really, do, n't, care,...
# 9       2006  [[Hunters, What, do, you, think, about, when, ...
# 10      2006  [[Bomberman, if, you, liked, the, game, then, ...
# 11      2006  [[Hate, watching, those, anime, that, drag, on...
# 12      2006  [[Elfen, Lied, is, something, else], [Just, wa...
# 13      2006  [[=, =, =, Animation===Toei, did, a, pretty, g...
# 14      2006  [[Love, bread], [Ever, wondered, how, they, ma...
# 15      2006  [[Scrapped, Princess, is, a, quite, interestin...
# 16      2006  [[Slayers, is, a, comedy, adventure, fantasy, ...
# 17      2006  [[If, you, 'd, like, to, see, my, full, review...
# 18      2006  [[If, you, 'd, like, to, see, my, full, review...
# 19      2006  [[If, you, 'd, like, to, see, my, full, review...
# 20      2006  [[=, =, =, Animation===Quite], [nice, and, ste...
# 21      2006  [[As, the, name, suggests, this, anime, is, ab...
# 22      2006  [[It, 's, funny], [I, 'm, not, the, type, of, ...
# 23      2006  [[I, find, it, a, bit, disheartening, that, mo...
# 24      2006  [[Back, in, my, \"Maison, Ikkoku\, review, I, ...
# 25      2006  [[=, =, =, Foreword===In, this, review, I, mig...
# 26      2006  [[Samurai, Champloo, is, the, latest, work, fr...
# 27      2006  [[Tantei, Gakuen, Q, is, pretty, much, just, a...
# 28      2006  [[=, =, =, Animation===Looking, back, at, the,...
# 29      2006  [[First, let, me, say, that, I, was, n't, expe...
# 30      2006  [[Looking, for, a, show, to, laugh, your, ass,...
# 31      2006  [[An, anime, about, a, grade, school, boy, pla...
# 32      2006  [[I, first, found, Air, Gear, when, I, was, lo...
# 33      2006  [[Gah~, Ceray, 's, Review, Time, procrastinati...
#
#                                      normalized_sents
# 0   [[cowboy, bebop, episodic, series], [episodic,...
# 1   [[utawarerumono, manages, harem, animes, possi...
# 2   [[let, i\\'m, fan, boxing], [fact, pretty, hat...
# 3   [[saiyuki, animes, grabs, episode, wo, let, ep...
# 4   [[comedy, romance, based, manga, rumiko, takah...
# 5   [[anime, traveler, journeying, different, coun...
# 6   [[kare, kano, romance, anime, incredibly, grea...
# 7   [[overall, best, anime], [actually, seen, leve...
# 8   [[overall, honestly, care, opinions, anime, fu...
# 9   [[hunters, think, hear], [anime, people, killi...
# 10  [[bomberman, liked, game, like, anime], [think...
# 11  [[hate, watching, anime, drag, long, boring, s...
# 12  [[elfen, lied], [watching, minutes, episode, u...
# 13  [[=, =, =, animation===toei, pretty, good, job...
# 14  [[love, bread], [wondered], [anime, bread, bes...
# 15  [[scrapped, princess, interesting, genre, mix]...
# 16  [[slayers, comedy, adventure, fantasy, anime, ...
# 17  [[like, review, leave, comment, profile], [gli...
# 18  [[like, review, leave, comment, profile], [cha...
# 19  [[like, review, leave, comment, profile], [plo...
# 20  [[=, =, =, animation===quite], [nice, steady, ...
# 21  [[suggests, anime, load, useless, animals, sha...
# 22  [[funny], [m, type, person, sit, tv, day, watc...
# 23  [[find, bit, disheartening, fans, \"rumic\, ni...
# 24  [[\"maison, ikkoku\, review, mentioned, fans, ...
# 25  [[=, =, =, foreword===in, review, term, tsunde...
# 26  [[samurai, champloo, latest, work, writer, dir...
# 27  [[tantei, gakuen, q, pretty, detective, fairly...
# 28  [[=, =, =, animation===looking, original, gree...
# 29  [[let, expecting, going, film], [seeing, direc...
# 30  [[looking, laugh, ass], [look, ouran, high, sc...
# 31  [[anime, grade, school, boy, playing, board, g...
# 32  [[found, air, gear, looking, anime, air, got, ...
# 33  [[gah~, ceray, review, time, procrastination, ...
#           id workId reviewId  \
# 34     24715   1210       48
# 35    111322   1718       49
# 36     93678   1531       50
# 37    117607    445       53
# 38     76358     98       54
# ...      ...    ...      ...
# 1173   38552    237     1772
# 1174    8868   1575     1773
# 1175   89236   2926     1775
# 1176   43769   2924     1776
# 1177   59155   1699     1777
#
#                                                workName             postTime  \
# 34                                       NHK_ni_Youkoso  2007-01-01 04:01:00
# 35                                        Winter_Garden  2007-01-01 07:47:00
# 36    Shakugan_no_Shana_SP__Koi_to_Onsen_no_Kougai_G...  2007-01-02 12:06:00
# 37                       Tales_of_Eternia_The_Animation  2007-01-04 17:21:00
# 38                                             Mai-HiME  2007-01-06 22:44:00
# ...                                                 ...                  ...
# 1173                         Koukyoushihen_Eureka_Seven  2007-12-31 06:15:00
# 1174                    Code_Geass__Hangyaku_no_Lelouch  2007-12-31 06:40:00
# 1175                                   Myself__Yourself  2007-12-31 13:24:00
# 1176                             ef__A_Tale_of_Memories  2007-12-31 14:05:00
# 1177                                     Romeo_x_Juliet  2007-12-31 14:28:00
#
#      episodesSeen         author peopleFoundUseful overallRating storyRating  \
# 34             24  running_lemon                87            10          10
# 35              2        martino                29             8           8
# 36              1        martino                19             7           6
# 37             13          Tenks                52             3           1
# 38             26         Hiromi               106             9           9
# ...           ...            ...               ...           ...         ...
# 1173           50         Signal                 7             6           6
# 1174           25         Signal                 6             7           7
# 1175           13     NightNLght                 6             9           7
# 1176           12     NightNLght                14            10          10
# 1177           24        andrael                17             6           5
#
#      animationRating soundRating characterRating enjoymentRating  \
# 34                 8          10              10               9
# 35                 5           8               7               8
# 36                 9           9               7               6
# 37                 5           7               1               5
# 38                 9           8               9               9
# ...              ...         ...             ...             ...
# 1173               8           8               7               6
# 1174               8          10               7               7
# 1175               8           0               8               9
# 1176              10          10              10              10
# 1177               7           7               6               7
#
#                                                  review postTime2  \
# 34    NHK ni Youkoso is an anime based off a novel a...      2007
# 35    ===Foreword===As you might know, this is a spi...      2007
# 36    ===Animation===It's very good, but it doesn't ...      2007
# 37    Most people would watch something titled &quot...      2007
# 38    Mai-HiME sports the story of Tokiha Mai and he...      2007
# ...                                                 ...       ...
# 1173  For the anime fanatics that had watched Evange...      2007
# 1174  Well for Sci-Fi with some magic this anime fan...      2007
# 1175  Honestly, I hated this series.  Thought it was...      2007
# 1176  Masterpiece, quick and easy.     Everything ab...      2007
# 1177  In a word: disappointing.  The early episodes ...      2007
#
#                                         tokenized_sents  \
# 34    [[NHK, ni, Youkoso, is, an, anime, based, off,...
# 35    [[=, =, =, Foreword===As, you, might, know, th...
# 36    [[=, =, =, Animation===It, 's, very, good, but...
# 37    [[Most, people, would, watch, something, title...
# 38    [[Mai, HiME, sports, the, story, of, Tokiha, M...
# ...                                                 ...
# 1173  [[For, the, anime, fanatics, that, had, watche...
# 1174  [[Well, for, Sci, Fi, with, some, magic, this,...
# 1175  [[Honestly, I, hated, this, series], [Thought,...
# 1176  [[Masterpiece, quick, and, easy], [Everything,...
# 1177  [[In, a, word, disappointing], [The, early, ep...
#
#                                        normalized_sents
# 34    [[nhk, ni, youkoso, anime, based, novel, manga...
# 35    [[=, =, =, foreword===as, know, spin, di, gi, ...
# 36    [[=, =, =, animation===it, good, good, animati...
# 37    [[people, watch, titled, quot;tales, of&quot, ...
# 38    [[mai, hime, sports, story, tokiha, mai, broth...
# ...                                                 ...
# 1173  [[anime, fanatics, watched, evangelion, anime,...
# 1174  [[sci, fi, magic, anime, fanatics], [], [usual...
# 1175  [[honestly, hated, series], [thought, complete...
# 1176  [[masterpiece, quick, easy], [series, spews, q...
# 1177  [[word, disappointing], [early, episodes, show...
#
# [1144 rows x 18 columns]
#           id workId reviewId                         workName  \
# 1178   34907   1735     1782               Naruto__Shippuuden
# 1179   33206   1559     1783  Shijou_Saikyou_no_Deshi_Kenichi
# 1180  109746    667     1785      Kashimashi__Girl_Meets_Girl
# 1181   94841    144     1786                            Kanon
# 1182   59624    120     1788                    Fruits_Basket
# ...      ...    ...      ...                              ...
# 5623   44292    427    10877                     Kaleido_Star
# 5624   97691   3446    10878          Biohazard__Degeneration
# 5625   25801    329    10881                         Planetes
# 5626   62165   1690    10889                         Bokurano
# 5627   77564    879    10890                           Simoun
#
#                  postTime episodesSeen         author peopleFoundUseful  \
# 1178  2008-01-01 10:06:00               puppydog20038                32
# 1179  2008-01-01 10:39:00           50         gels31                64
# 1180  2008-01-01 14:59:00           12      Master10K                46
# 1181  2008-01-01 15:01:00           13  anonimus91136                79
# 1182  2008-01-01 15:53:00           26           kara                 4
# ...                   ...          ...            ...               ...
# 5623  2008-12-31 17:43:00           51       Suzuhana                 9
# 5624  2008-12-31 17:44:00            1       milhouse                 6
# 5625  2008-12-31 18:37:00           26        kiriska                51
# 5626  2008-12-31 21:51:00           24      snivek101                 2
# 5627  2008-12-31 22:04:00           26   hearmescream                39
#
#      overallRating storyRating animationRating soundRating characterRating  \
# 1178            10           9               8           9              10
# 1179             9           8               6           7              10
# 1180             8           8               8           8               7
# 1181             8           8               6           7               9
# 1182             8           8               7           9              10
# ...            ...         ...             ...         ...             ...
# 5623            10          10               9           9              10
# 5624             3           3               9           5               3
# 5625             9           9               9           8               8
# 5626             8           8               7           7               9
# 5627            10          10               6           7              10
#
#      enjoymentRating                                             review  \
# 1178               9  this is a very good series if you were a big f...
# 1179               8  History's Greatest Disciple Kenichi starts off...
# 1180               8  Kashimasi ~Girl Meets Girl~ is a Sci-fi, Gende...
# 1181               8  Kanon 2002, the predecessor of our beloved Kan...
# 1182              10  fruits basket was very enjoyable to watch and ...
# ...              ...                                                ...
# 5623              10  If your in for a heartwarming, growing experie...
# 5624               3  I'm a big Resident Evil fan (loved all the gam...
# 5625               9  It is a time... when collecting space debris.....
# 5626               9  I'll just comment on the story only because I ...
# 5627              10  I recall back when I was first told about Simo...
#
#      postTime2                                    tokenized_sents  \
# 1178      2008  [[this, is, a, very, good, series, if, you, we...
# 1179      2008  [[History, 's, Greatest, Disciple, Kenichi, st...
# 1180      2008  [[Kashimasi, ~Girl, Meets, Girl~, is, a, Sci, ...
# 1181      2008  [[Kanon, 2002, the, predecessor, of, our, belo...
# 1182      2008  [[fruits, basket, was, very, enjoyable, to, wa...
# ...        ...                                                ...
# 5623      2008  [[If, your, in, for, a, heartwarming, growing,...
# 5624      2008  [[I, 'm, a, big, Resident, Evil, fan, loved, a...
# 5625      2008  [[It, is, a, time], [when, collecting, space, ...
# 5626      2008  [[I, 'll, just, comment, on, the, story, only,...
# 5627      2008  [[I, recall, back, when, I, was, first, told, ...
#
#                                        normalized_sents
# 1178  [[good, series, big, fan, original, time, skip...
# 1179  [[history, greatest, disciple, kenichi, starts...
# 1180  [[kashimasi, ~girl, meets, girl~, sci, fi, gen...
# 1181  [[kanon, predecessor, beloved, kanon], [kyoto,...
# 1182  [[fruits, basket, enjoyable, watch, read.i, di...
# ...                                                 ...
# 5623  [[heartwarming, growing, experience, kaleido, ...
# 5624  [[m, big, resident, evil, fan, loved, games, l...
# 5625  [[time], [collecting, space, debris, important...
# 5626  [[comment, story, feel, important], [firstly, ...
# 5627  [[recall, told, simoun, came, read, synopsis, ...
#
# [4450 rows x 18 columns]
#            id workId reviewId                         workName  \
# 5628   114617   4975    10892                       ChäoS_HEAd
# 5629    93147    974    10896                      Dead_Leaves
# 5630    62723    226    10897                       Elfen_Lied
# 5631    13742   3297    10900             Aria_The_Origination
# 5632    62902   2593    10901  Kara_no_Kyoukai_1__Fukan_Fuukei
# ...       ...    ...      ...                              ...
# 10787   51836    322    21907                    Paradise_Kiss
# 10788   17293    877    21908                             Nana
# 10789  120103   2476    21909                      School_Days
# 10790   48841   5630    21910                  Higashi_no_Eden
# 10791   96387   3299    21913      H2O__Footprints_in_the_Sand
#
#                   postTime episodesSeen          author peopleFoundUseful  \
# 5628   2009-01-01 00:16:00           12      gdavge2003                 8
# 5629   2009-01-01 04:37:00            1   Mugiwara-Pyon                10
# 5630   2009-01-01 04:49:00           13   Mugiwara-Pyon                 1
# 5631   2009-01-01 08:10:00           13  chidori3souske                 6
# 5632   2009-01-01 08:12:00            1  chidori3souske                 2
# ...                    ...          ...             ...               ...
# 10787  2009-12-31 16:36:00           12     Midori84hua                 2
# 10788  2009-12-31 16:39:00           47     Midori84hua                 5
# 10789  2009-12-31 16:42:00           12     Midori84hua                 4
# 10790  2009-12-31 19:13:00           11        TheLlama                77
# 10791  2009-12-31 20:55:00           12          sayian                 5
#
#       overallRating storyRating animationRating soundRating characterRating  \
# 5628              7           8              10           8               7
# 5629              9           8               8           9               9
# 5630              7           8               8           9               7
# 5631              9           9              10           9              10
# 5632              9           8              10           9               9
# ...             ...         ...             ...         ...             ...
# 10787            10          10              10           9              10
# 10788            10          10              10          10              10
# 10789             8           8               8           8               8
# 10790             9           8              10          10               9
# 10791             5           3               4           5               5
#
#       enjoymentRating                                             review  \
# 5628                9  ChaoS;HEAd is a psychological anime with some ...
# 5629                9  This is some kind of weird funky kind of anime...
# 5630                9  This is a gore anime with nudity which mainly ...
# 5631                9  Aria Series ReviewThis review will cover seaso...
# 5632                9  This movie is based on a light novel by Nasu K...
# ...               ...                                                ...
# 10787               9  Beautiful art, fashionable clothes, cool chara...
# 10788              10  If you liked Paradise Kiss you'll like this on...
# 10789               7  I2m not sure if I liked this one. It follows a...
# 10790              10  \"The abuse of greatness is when it disjoins r...
# 10791               5  Art: Terrible, this Anime was made in 2008. Ma...
#
#       postTime2                                    tokenized_sents  \
# 5628       2009  [[ChaoS;HEAd, is, a, psychological, anime, wit...
# 5629       2009  [[This, is, some, kind, of, weird, funky, kind...
# 5630       2009  [[This, is, a, gore, anime, with, nudity, whic...
# 5631       2009  [[Aria, Series, ReviewThis, review, will, cove...
# 5632       2009  [[This, movie, is, based, on, a, light, novel,...
# ...         ...                                                ...
# 10787      2009  [[Beautiful, art, fashionable, clothes, cool, ...
# 10788      2009  [[If, you, liked, Paradise, Kiss, you, 'll, li...
# 10789      2009  [[I2, m, not, sure, if, I, liked, this, one], ...
# 10790      2009  [[\"The, abuse, of, greatness, is, when, it, d...
# 10791      2009  [[Art], [Terrible, this, Anime, was, made, in,...
#
#                                         normalized_sents
# 5628   [[chaos;head, psychological, anime, action, go...
# 5629   [[kind, weird, funky, kind, anime, takes, plac...
# 5630   [[gore, anime, nudity, mainly, focuses, women,...
# 5631   [[aria, series, reviewthis, review, cover, sea...
# 5632   [[movie, based, light, novel, nasu, kinonko, w...
# ...                                                  ...
# 10787  [[beautiful, art, fashionable, clothes, cool, ...
# 10788  [[liked, paradise, kiss, like], [clothes, fash...
# 10789  [[i2, m, sure, liked], [follows, strange, stor...
# 10790  [[\"the, abuse, greatness, disjoins, remorse, ...
# 10791  [[art], [terrible, anime], [main, character, d...
#
# [5164 rows x 18 columns]
#            id workId reviewId                                  workName  \
# 10792   37220   2034    21919                            Lovely★Complex
# 10793  116262   1458    21927                   Uchuu_no_Kishi_Tekkaman
# 10794   54453   1096    21930       Kidou_Keisatsu_Patlabor_2_the_Movie
# 10795   47515   4898    21931                              Kuroshitsuji
# 10796   60697    345    21932                Eikoku_Koi_Monogatari_Emma
# ...       ...    ...      ...                                       ...
# 14995   30576    121    31205                       Fullmetal_Alchemist
# 14996   49847   1689    31206                     Byousoku_5_Centimeter
# 14997   33545   2167    31209                                   Clannad
# 14998   54369   8525    31214                  Kami_nomi_zo_Shiru_Sekai
# 14999   87316   1259    31216  Saint_Seiya__Tenkai-hen_Josou_-_Overture
#
#                   postTime episodesSeen           author peopleFoundUseful  \
# 10792  2010-01-01 05:17:00           24  NeonLoveCookies                 0
# 10793  2010-01-01 12:48:00            1     stoppedxtime                 4
# 10794  2010-01-01 15:53:00            1         Archaeon               119
# 10795  2010-01-01 17:10:00           23      xxxxxx81594                 3
# 10796  2010-01-01 17:28:00           12         inkmouse                 6
# ...                    ...          ...              ...               ...
# 14995  2010-10-08 12:59:00           51            otyme                 2
# 14996  2010-10-08 13:25:00            3    kirathesavior                 1
# 14997  2010-10-08 16:11:00           23           xm0123                 6
# 14998  2010-10-08 20:28:00            1        Sugarsync                 6
# 14999  2010-10-09 00:18:00            1           rahvii                10
#
#       overallRating storyRating animationRating soundRating characterRating  \
# 10792            10          10              10          10              10
# 10793             2           5               3           1               5
# 10794             8           8               9           7               8
# 10795             9           8              10           9               8
# 10796             6          10               6           7               6
# ...             ...         ...             ...         ...             ...
# 14995            10           9               8           7              10
# 14996             8           8               9           9               8
# 14997            10           9               9          10              10
# 14998             9           9               8           9               8
# 14999             6           6               6           4               7
#
#       enjoymentRating                                             review  \
# 10792              10  One of the best anime i have ever seen, and ma...
# 10793               1  Okay, so for my Anime Parody show my friend su...
# 10794               9  If you ask the average anime fan for an intell...
# 10795               8  *STORY* - 8/10 - Like most anime, Kuroshitsuji...
# 10796               7  At the beginning, I was very much fascinated b...
# ...               ...                                                ...
# 14995               9  Story:The story is about Edward Elric (I found...
# 14996              10  this movie was really heart warming. the chara...
# 14997              10  Clannad was originally a visual novel for the ...
# 14998               9  *this is the detail from the review i wrote in...
# 14999               7  First half of the movie is extremely boring. T...
#
#       postTime2                                    tokenized_sents  \
# 10792      2010  [[One, of, the, best, anime, i, have, ever, se...
# 10793      2010  [[Okay, so, for, my, Anime, Parody, show, my, ...
# 10794      2010  [[If, you, ask, the, average, anime, fan, for,...
# 10795      2010  [[STORY, 8/10], [Like, most, anime, Kuroshitsu...
# 10796      2010  [[At, the, beginning, I, was, very, much, fasc...
# ...         ...                                                ...
# 14995      2010  [[Story], [The, story, is, about, Edward, Elri...
# 14996      2010  [[this, movie, was, really, heart, warming], [...
# 14997      2010  [[Clannad, was, originally, a, visual, novel, ...
# 14998      2010  [[this, is, the, detail, from, the, review, i,...
# 14999      2010  [[First, half, of, the, movie, is, extremely, ...
#
#                                         normalized_sents
# 10792  [[best, anime, seen, maybe, cried], [storie, w...
# 10793  [[okay, anime, parody, friend, suggested, watc...
# 10794  [[ask, average, anime, fan, intelligent, craft...
# 10795  [[story], [like, anime, kuroshitsuji, contains...
# 10796  [[beginning, fascinated], [directly, point, pl...
# ...                                                  ...
# 14995  [[story], [story, edward, elric, found, eduard...
# 14996  [[movie, heart, warming], [characters, unique,...
# 14997  [[clannad, originally, visual, novel, pc], [ky...
# 14998  [[detail, review, wrote, manga*tamiki, wakiki,...
# 14999  [[half, movie, extremely, boring], [story, tim...
#
# [4208 rows x 18 columns]

# %%
rawEmbeddings.keys()
# Out:
# dict_keys(['2006', '2007', '2008', '2009', '2010'])

# %%
def getDivergenceDF(word, embeddingsDict):
    dists = []
    cats = sorted(set(embeddingsDict.keys()))
    dists = {}
    print(word)
    for cat in cats:
        dists[cat] = []
        for embed in embeddingsDict[cat][1:]:
            dists[cat].append(np.abs(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cat][0][word], axis = 0),
                                                                             np.expand_dims(embed[word], axis = 0))[0,0]))
    return pandas.DataFrame(dists, index = cats)

# %%
targetWord = 'romance'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# romance

# %%
targetWord = 'hate'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# hate

# %%
def findDiverence(word, embeddingsDict):
    cats = sorted(set(embeddingsDict.keys()))
    
    dists = []
    for embed in embeddingsDict[cats[0]][1:]:
        dists.append(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cats[0]][0][word], axis = 0), np.expand_dims(embed[word], axis = 0))[0,0])
    return sum(dists)

def findMostDivergent(embeddingsDict):
    words = []
    for embeds in embeddingsDict.values():
        for embed in embeds:
            words += list(embed.wv.vocab.keys())
    words = set(words)
    print("Found {} words to compare".format(len(words)))
    return sorted([(w, findDiverence(w, embeddingsDict)) for w in words], key = lambda x: x[1], reverse=True)

# %%
wordDivergences = findMostDivergent(comparedEmbeddings)
# Out:
# Found 232 words to compare

# %%
wordDivergences[:20]
# Out:
# [('follow', 4.533234171569347),
#  ('poor', 4.48951767757535),
#  ('easy', 4.267359554767609),
#  ('score', 4.2026882683858275),
#  ('type', 4.120262373704463),
#  ('endings', 4.115860195830464),
#  ('occasionally', 4.064325328916311),
#  ('starts', 4.038073130650446),
#  ('alot', 4.010442974744365),
#  ('jin', 3.9889801379758865),
#  ('fairly', 3.987789226695895),
#  ('special', 3.983005986083299),
#  ('harem', 3.9792249986203387),
#  ('develop', 3.9766561463475227),
#  ('x', 3.972365794237703),
#  ('kind', 3.9683358538895845),
#  ('enjoyed', 3.902394875884056),
#  ('enjoyable', 3.894607152789831),
#  ('theme', 3.89224636554718),
#  ('goes', 3.8672789566917345)]

# %%
wordDivergences[-20:]
# Out:
# [('sound', 2.6862601190805435),
#  ('expect', 2.6839626133441925),
#  ('samurai', 2.669640690088272),
#  ('things', 2.6684865057468414),
#  ('leave', 2.6638589799404144),
#  ('good', 2.6277555525302887),
#  ('time', 2.5542499274015427),
#  ('find', 2.5482065677642822),
#  ('watch', 2.546863228082657),
#  ('story', 2.514767110347748),
#  ('bit', 2.498124837875366),
#  ('number', 2.4540416598320007),
#  ('episode', 2.417812466621399),
#  ('stories', 2.4026727080345154),
#  ('ranma', 2.401169627904892),
#  ('hunter', 2.3584823608398438),
#  ('characters', 2.31142121553421),
#  ('character', 2.253087967634201),
#  ('seen', 1.8597404062747955),
#  ('anime', 1.5622852444648743)]

# %%
targetWord = wordDivergences[0][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# follow

# %%
targetWord = wordDivergences[-1][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# anime

# %%
'''
It reveals that audience still use similar metrics of measurement when they evaluate an animation across these years. And some of their taste remain stable since adjectives like "best","expect" remain stable. But their measurement of evaluation for bad works seem to change
'''
# Out:
# '\nIt reveals that audience still use similar metrics of measurement when they evaluate an animation across these years. And some of their taste remain stable since adjectives like "best","expect" remain stable. But their measurement of evaluation for bad works seem to change\n'

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

# %%
df_IM = pd.read_csv("/Users/shiyipeng/Downloads/imdb-dataset-sentiment-analysis-in-csv-format/Train.csv")
df_IM = df_IM.iloc[0:15000,:]
df_IM.head
# Out:
# <bound method NDFrame.head of                                                     text  label
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 14995  <br /><br />Summary: Not worth the film<br /><...      0
# 14996  I got to see this just this last Friday at the...      1
# 14997  OK, I have watched the original French version...      0
# 14998  The only reason I know this film exists is bec...      0
# 14999  Simply put, there are two parts of this series...      1
#
# [15000 rows x 2 columns]>

# %%
x_train = df_IM.loc[0:7499,'text'].values
y_train = df_IM.loc[0:7499,'label'].values
x_test = df_IM.loc[7500:15000,'text'].values
y_test = df_IM.loc[7500:15000,'label'].values
tokenize_obj = Tokenizer()
total_review = x_train + x_test
tokenize_obj.fit_on_texts(total_review)

# %%
max_length = max([len(s.split())for s in total_review])
vocav_size = len(tokenize_obj.word_index) + 1

# %%
x_train_tokens = tokenize_obj.texts_to_sequences(x_train)
x_test_tokens = tokenize_obj.texts_to_sequences(x_test)
x_train_pad = pad_sequences(x_train_tokens,maxlen= max_length, padding='post')
x_test_pad = pad_sequences(x_test_tokens,maxlen= max_length, padding='post')

# %%
import keras
from tensorflow.keras import Sequential

from keras.layers import Dense,Embedding,LSTM,GRU
from keras.layers.embeddings import Embedding

Embedding_DIM = 100
model = keras.Sequential()
model.add(Embedding(vocav_size,Embedding_DIM,input_length = max_length))
model.add(GRU(units=32,dropout=0.2,recurrent_dropout=0.2))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss= 'binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 2980, 100)         7234700
# _________________________________________________________________
# gru_4 (GRU)                  (None, 32)                12768
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 7,247,501
# Trainable params: 7,247,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train_pad,y_train,batch_size=128,validation_data = (x_test_pad,y_test),epochs=25,verbose=2)
# Out:
# Train on 7500 samples, validate on 7500 samples
# Epoch 1/25
#  - 193s - loss: 0.6941 - accuracy: 0.4972 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 2/25
#  - 184s - loss: 0.6934 - accuracy: 0.4920 - val_loss: 0.6944 - val_accuracy: 0.4960
# Epoch 3/25
#  - 197s - loss: 0.6936 - accuracy: 0.5047 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 4/25
#  - 195s - loss: 0.6933 - accuracy: 0.5011 - val_loss: 0.6936 - val_accuracy: 0.4960
# Epoch 5/25
#  - 194s - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 6/25
#  - 211s - loss: 0.6935 - accuracy: 0.4989 - val_loss: 0.6935 - val_accuracy: 0.4960
# Epoch 7/25
#  - 219s - loss: 0.6934 - accuracy: 0.4977 - val_loss: 0.6936 - val_accuracy: 0.4960
# Epoch 8/25
#  - 200s - loss: 0.6933 - accuracy: 0.5003 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 9/25
#  - 181s - loss: 0.6932 - accuracy: 0.5069 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 10/25
#  - 183s - loss: 0.6931 - accuracy: 0.5045 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 11/25
#  - 204s - loss: 0.6931 - accuracy: 0.5029 - val_loss: 0.6938 - val_accuracy: 0.4960
# Epoch 12/25
#  - 212s - loss: 0.6933 - accuracy: 0.5057 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 13/25
#  - 200s - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6936 - val_accuracy: 0.4960
# Epoch 14/25
#  - 192s - loss: 0.6932 - accuracy: 0.5045 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 15/25
#  - 197s - loss: 0.6933 - accuracy: 0.5053 - val_loss: 0.6936 - val_accuracy: 0.4960
# Epoch 16/25
#  - 186s - loss: 0.6932 - accuracy: 0.5067 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 17/25
#  - 206s - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6935 - val_accuracy: 0.4960
# Epoch 18/25
#  - 193s - loss: 0.6932 - accuracy: 0.5073 - val_loss: 0.6935 - val_accuracy: 0.4960
# Epoch 19/25
#  - 192s - loss: 0.6934 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 20/25
#  - 199s - loss: 0.6933 - accuracy: 0.5083 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 21/25
#  - 201s - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 22/25
#  - 197s - loss: 0.6931 - accuracy: 0.5059 - val_loss: 0.6935 - val_accuracy: 0.4960
# Epoch 23/25
#  - 196s - loss: 0.6934 - accuracy: 0.5039 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 24/25
#  - 193s - loss: 0.6933 - accuracy: 0.5013 - val_loss: 0.6936 - val_accuracy: 0.4960
# Epoch 25/25
#  - 185s - loss: 0.6931 - accuracy: 0.5072 - val_loss: 0.6937 - val_accuracy: 0.4960

# %%
test1 = review_df['review'][200]
test2 = review_df['review'][2]
test3 = review_df['review'][54]
test4 = review_df['review'][98]
test5 = review_df['review'][900]
test6 = review_df['review'][1009]
test_sample = [test1+test2+test3+test4+test5+test6]

# %%
test_sample_token = tokenize_obj.texts_to_sequences(test_sample)
test_sample_pad = pad_sequences(test_sample_token,maxlen= max_length)
model.predict(test_sample_pad)
# Out:
# array([[0.49441338]], dtype=float32)

# %%
test1
# Out:
# "Where to begin!? One Piece is a very adventurous story. Never in one place for too long the story is full fun and unusual things.One Piece is about a rather childish 17 year old boy (Monkey D. Luffy) who aspires to reach his dreams of becoming Pirate King and keeping the promises he's made.  Meeting many a friend along the way the story progresses through many story arcs that build the personality and integrity of each character.The first friend and crew member he makes is his ever faithful First Mate (Zoro) who also has a dream to achieve.I am not going to explain every                  character. That would take too long and it would spoil some of the fun. The best way to understand this anime is to watch it.One Piece is a really good story, perfect for anyone who likes pirate stories. Though a very long and yet unfinished story thus far, I find it to be very enjoyable. The comedy is some of the best I have seen in any anime.I recommend watching in its original japanese with english subtitles (preferably fan-subbed). The dubbed version by 4kids entertainment is TERRIBLE! They have also stopped dubbing it anyway. Funimation has taken over dubbing One Piece in English and has done a far better job.As far as fansub groups go, I recommend Kaizoku-Fansubs, Vegapunk and Instantz Noob Production.Kaizoku-fansubs (K-F)started subbing the series from the beginning and they are still subbing it today with flying colors. They are the way to go for most of the available episodes. The other groups have what goes after the episodes K-F has done so far.Good luck finding and downloading without any problems. Torrent is the easiest way to get them. Otherwise you can get them from IRC.This is my favorite anime above all so...Enjoy the show!        "

# %%
review_df.shape
# Out:
# (5000, 21)

# %%
test_loss, test_acc = model.evaluate(x_test_pad, y_test)
print(test_acc)
# Out:
# 7500/7500 [==============================] - 74s 10ms/step
# 0.4959999918937683
